# %%
import threading
import time
def coding():
    for x in range(2):
        print('第{}次写代码'.format(x+1))
        time.sleep(0.5)
def drawing():
    for x in range(2):
        print('第{}次画画'.format(x+1))
        time.sleep(0.5)
def single_thread():
    coding()
    drawing()
def multi_thread():
    t1 = threading.Thread(target=coding)
    t2 = threading.Thread(target=drawing)
    t1.start()
    t2.start()
if __name__ == '__main__':
    #single_thread()
    multi_thread()
# Out:
# 第1次写代码
# 第1次画画
# 第2次写代码
# 第2次画画

# %%
threading.current_thread()  #可以查看当前的线程的信息
threading.enumerate() #可以看到当前线程的数量
# Out:
# [<_MainThread(MainThread, started 18040)>,
#  <Thread(Thread-4, started daemon 2480)>,
#  <Heartbeat(Thread-5, started daemon 8792)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 6472)>,
#  <ParentPollerWindows(Thread-3, started daemon 11936)>]

# %%
"""
为了让线程代码更好的封装。可以使用threading模块下的Thread类，
继承自这个类，然后实现run方法，(运行时还是用start哦)
线程就会自动运行run方法中的代码。示例代码如下：
"""

import threading
import time
class CodingThread(threading.Thread):
    def run(self):
        for x in range(2):
            print('第{}次写代码'.format(x+1))
            time.sleep(0.5)
class DrawingThread(threading.Thread):
    def run(self):
        for x in range(2):
            print('第{}次画画'.format(x+1))
            time.sleep(0.5)
def multi_thread():
    t1 = CodingThread()
    t2 = DrawingThread()
    t1.start()
    t2.start()
if __name__ == '__main__':
    multi_thread()
# Out:
# 第1次写代码
# 第1次画画
# 第2次写代码
# 第2次画画

# %% [markdown]
# # 多线程都是在同一个进程中运行的。因此在进程中的全局变量所有线程都是可共享的。这就造成了一个问题，因为线程执行的顺序是无序的。有可能会造成数据错误。比如以下代码：

# %%
import threading
NUM = 0
def num_add_one():
    global NUM
    for i in range(1000000):
        NUM += 1
    print(str(NUM) + '\n')
class Num_thread(threading.Thread):
    def run(self):
        num_add_one()
def multi_thread():
    t1 = Num_thread()
    t2 = Num_thread()
    t1.start()
    t2.start()
multi_thread()
# Out:
# 1362802
#
# 1387599

# %% [markdown]
# # 为了解决以上使用共享全局变量的问题。threading提供了一个Lock类，这个类可以在某个线程访问某个变量的时候加锁，其他线程此时就不能进来，直到当前线程处理完后，把锁释放了，其他线程才能进来处理。示例代码如下：

# %%
import threading
NUM = 0
glock = threading.Lock()
def num_add_one():
    global NUM
    
    glock.acquire()
    for i in range(1000000):
        NUM += 1
    glock.release()
    print(str(NUM) + '\n')
class Num_thread(threading.Thread):
    def run(self):
        num_add_one()
def multi_thread():
    t1 = Num_thread()
    t2 = Num_thread()
    t1.start()
    t2.start()
multi_thread()
# Out:
# 1000000
#
# 2000000

# %% [markdown]
# # Lock版本生产者和消费者模式：
# ## 生产者的线程专门用来生产一些数据，然后存放到一个中间的变量中。消费者再从这个中间的变量中取出数据进行消费。但是因为要使用中间变量，中间变量经常是一些全局变量，因此需要使用锁来保证数据完整性。以下是使用threading.Lock锁实现的“生产者与消费者模式”的一个例子：

# %%
import threading
import random
import time

gMoney = 1000
gLock = threading.Lock()
# 记录生产者生产的次数，达到10次就不再生产
gTimes = 0

class Producer(threading.Thread):
    def run(self):
        global gMoney
        global gLock
        global gTimes
        while True:
            money = random.randint(100, 1000)
            gLock.acquire()
            # 如果已经达到10次了，就不再生产了
            if gTimes >= 10:
                gLock.release()
                break
            gMoney += money
            print('%s当前存入%s元钱，剩余%s元钱' % (threading.current_thread(), money, gMoney))
            gTimes += 1
            time.sleep(0.5)
            gLock.release()

class Consumer(threading.Thread):
    def run(self):
        global gMoney
        global gLock
        global gTimes
        while True:
            money = random.randint(100, 1000)
            gLock.acquire()
            if gMoney > money:
                gMoney -= money
                print('%s当前取出%s元钱，剩余%s元钱' % (threading.current_thread(), money, gMoney))
                time.sleep(0.5)
            else:
                # 如果钱不够了，有可能是已经超过了次数，这时候就判断一下
                if gTimes >= 10:
                    gLock.release()
                    break
                print("%s当前想取%s元钱，剩余%s元钱，不足！" % (threading.current_thread(),money,gMoney))
            gLock.release()

def main():
    for x in range(2):
        Producer(name='生产者线程%d'%x).start()

    for x in range(2):
        Consumer(name='消费者线程%d'%x).start()


if __name__ == '__main__':
    main()
# Out:
# <Producer(生产者线程0, started 16108)>当前存入971元钱，剩余1971元钱
# <Producer(生产者线程1, started 12752)>当前存入964元钱，剩余2935元钱
# <Producer(生产者线程1, started 12752)>当前存入992元钱，剩余3927元钱
# <Consumer(消费者线程1, started 12652)>当前取出973元钱，剩余2954元钱
# <Producer(生产者线程0, started 16108)>当前存入111元钱，剩余3065元钱
# <Consumer(消费者线程0, started 17232)>当前取出402元钱，剩余2663元钱
# <Producer(生产者线程1, started 12752)>当前存入313元钱，剩余2976元钱
# <Consumer(消费者线程1, started 12652)>当前取出223元钱，剩余2753元钱
# <Consumer(消费者线程1, started 12652)>当前取出707元钱，剩余2046元钱
# <Consumer(消费者线程0, started 17232)>当前取出913元钱，剩余1133元钱
# <Consumer(消费者线程0, started 17232)>当前取出201元钱，剩余932元钱
# <Producer(生产者线程0, started 16108)>当前存入517元钱，剩余1449元钱
# <Consumer(消费者线程1, started 12652)>当前取出712元钱，剩余737元钱
# <Producer(生产者线程1, started 12752)>当前存入427元钱，剩余1164元钱
# <Consumer(消费者线程0, started 17232)>当前取出202元钱，剩余962元钱
# <Producer(生产者线程0, started 16108)>当前存入834元钱，剩余1796元钱
# <Consumer(消费者线程1, started 12652)>当前取出473元钱，剩余1323元钱
# <Producer(生产者线程1, started 12752)>当前存入665元钱，剩余1988元钱
# <Consumer(消费者线程0, started 17232)>当前取出862元钱，剩余1126元钱
# <Consumer(消费者线程0, started 17232)>当前取出826元钱，剩余300元钱
# <Consumer(消费者线程1, started 12652)>当前想取572元钱，剩余300元钱，不足！
# <Consumer(消费者线程1, started 12652)>当前想取669元钱，剩余300元钱，不足！
# <Consumer(消费者线程1, started 12652)>当前想取858元钱，剩余300元钱，不足！
# <Producer(生产者线程0, started 16108)>当前存入328元钱，剩余628元钱
# <Consumer(消费者线程0, started 17232)>当前取出515元钱，剩余113元钱

# %% [markdown]
# # Condition版的生产者与消费者模式：
# ## Lock版本的生产者与消费者模式可以正常的运行。但是存在一个不足，在消费者中，总是通过while True死循环并且上锁的方式去判断钱够不够。上锁是一个很耗费CPU资源的行为。因此这种方式不是最好的。还有一种更好的方式便是使用threading.Condition来实现。threading.Condition可以在没有数据的时候处于阻塞等待状态。一旦有合适的数据了，还可以使用notify相关的函数来通知其他处于等待状态的线程。这样就可以不用做一些无用的上锁和解锁的操作。可以提高程序的性能。首先对threading.Condition相关的函数做个介绍，threading.Condition类似threading.Lock，可以在修改全局数据的时候进行上锁，也可以在修改完毕后进行解锁。以下将一些常用的函数做个简单的介绍：
# ## acquire：上锁。
# ## release：解锁。
# ## wait：将当前线程处于等待状态，并且会释放锁。可以被其他线程使用notify和notify_all函数唤醒。被唤醒后会继续等待上锁，上锁后继续执行下面的代码。
# ## notify：通知某个正在等待的线程，默认是第1个等待的线程。
# ## notify_all：通知所有正在等待的线程。notify和notify_all不会释放锁。并且需要在release之前调用。

# %%
import threading
import random
import time

gMoney = 1000
gCondition = threading.Condition()
gTimes = 0
gTotalTimes = 5

class Producer(threading.Thread):
    def run(self):
        global gMoney
        global gCondition
        global gTimes
        while True:
            money = random.randint(100, 1000)
            gCondition.acquire()
            if gTimes >= gTotalTimes:
                gCondition.release()
                print('当前生产者总共生产了%s次'%gTimes)
                break
            gMoney += money
            print('%s当前存入%s元钱，剩余%s元钱' % (threading.current_thread(), money, gMoney))
            gTimes += 1
            time.sleep(0.5)
            gCondition.notify_all()
            gCondition.release()

class Consumer(threading.Thread):
    def run(self):
        global gMoney
        global gCondition
        while True:
            money = random.randint(100, 500)
            gCondition.acquire()
            # 这里要给个while循环判断，因为等轮到这个线程的时候
            # 条件有可能又不满足了
            while gMoney < money:
                if gTimes >= gTotalTimes:
                    gCondition.release()
                    return
                print('%s准备取%s元钱，剩余%s元钱，不足！'%(threading.current_thread(),money,gMoney))
                gCondition.wait()
            gMoney -= money
            print('%s当前取出%s元钱，剩余%s元钱' % (threading.current_thread(), money, gMoney))
            time.sleep(0.5)
            gCondition.release()

def main():
    for x in range(2):
        Producer(name='生产者线程%d'%x).start()

    for x in range(2):
        Consumer(name='消费者线程%d'%x).start()

if __name__ == '__main__':
    main()
# Out:
# <Producer(生产者线程0, started 17436)>当前存入995元钱，剩余1995元钱
# <Producer(生产者线程1, started 13932)>当前存入782元钱，剩余2777元钱
# <Producer(生产者线程1, started 13932)>当前存入411元钱，剩余3188元钱
# <Consumer(消费者线程1, started 17052)>当前取出181元钱，剩余3007元钱
# <Producer(生产者线程0, started 17436)>当前存入421元钱，剩余3428元钱
# <Consumer(消费者线程0, started 17644)>当前取出487元钱，剩余2941元钱
# <Producer(生产者线程1, started 13932)>当前存入177元钱，剩余3118元钱
# 当前生产者总共生产了5次<Consumer(消费者线程1, started 17052)>当前取出289元钱，剩余2829元钱
#
# <Consumer(消费者线程1, started 17052)>当前取出234元钱，剩余2595元钱
# 当前生产者总共生产了5次<Consumer(消费者线程0, started 17644)>当前取出345元钱，剩余2250元钱
#
# <Consumer(消费者线程1, started 17052)>当前取出176元钱，剩余2074元钱
# <Consumer(消费者线程0, started 17644)>当前取出352元钱，剩余1722元钱
# <Consumer(消费者线程1, started 17052)>当前取出333元钱，剩余1389元钱
# <Consumer(消费者线程0, started 17644)>当前取出140元钱，剩余1249元钱
# <Consumer(消费者线程1, started 17052)>当前取出312元钱，剩余937元钱
# <Consumer(消费者线程0, started 17644)>当前取出265元钱，剩余672元钱
# <Consumer(消费者线程1, started 17052)>当前取出175元钱，剩余497元钱
# <Consumer(消费者线程0, started 17644)>当前取出494元钱，剩余3元钱

# %% [markdown]
# # Queue线程安全队列：

# %%
from queue import Queue
q = Queue(5)  #创建一个先进先出的5个元素的队列。
q.put(1) #将数字1放入队列中
print(q.qsize())  #查看队列q的大小
print(q.empty())  #False 判断队列是否为空
for i in range(4):
    q.put(i)
print(q.full())  #判断队列是否满了
for i in range(5):
    print(q.get()) # 1 0 1 2 3 按照先到先出的原则弹出这些元素并在原队列中删除
print('队列q的长度为%d'%q.qsize())  #0
# Out:
# 1
# False
# True
# 1
# 0
# 1
# 2
# 3
# 队列q的长度为0

# %%
import requests 
from fake_useragent import UserAgent
from lxml import etree
import os
import re
import time
URLDATA = []
NAMEDATA =[]
def get_html_text(url,headers,timeout=5):
    try:
        resp = requests.get(url,headers=headers,timeout=timeout)
        resp.raise_for_status
       # resp.encoding = 'UTF-8' 
        return resp.text
    except:
        return ''
    
def xpathParser(text):
    html = etree.HTML(text)
    photo_xpath = '//*[@id="pic-detail"]/div/div[3]/div[2]/ul/li/div/div/a/img/@data-original'
    name_xpath = '//*[@id="pic-detail"]/div/div[3]/div[2]/ul/li/div/div/a/img/@alt'
    URLDATA.extend(html.xpath(photo_xpath))
    NAMEDATA.extend(html.xpath(name_xpath))

          
if __name__ =='__main__':
    time_start = time.perf_counter()
    row_url = 'http://www.doutula.com/photo/list/?page={}'
    headers = {"User-Agent": UserAgent().chrome}
    for i in range(0,10):
        url = row_url.format(i+1)
        print(url)
        text = get_html_text(url,headers)
        if text == '':
            print('url: {} 连接失败'.format(url))
        else:
           xpathParser(text)
    index = 1
    num_url = len(URLDATA)
    for url,name in zip(URLDATA,NAMEDATA):
        ext = os.path.splitext(url)[1].split('!')[0]
        row_file_name = name + ext
        # 去除Windows操作系统中规定文件名中不能含有的符号
        file_name = re.sub(r'[\\/:\*\?"<>\|]','',row_file_name)
        os.chdir(r'C:\Users\hc_lzp\爬虫\imags')
        with open(file_name,'wb') as f:
            f.write(requests.get(url,headers = headers ,timeout=5).content)
        print('\r任务已完成:{:.1f}%'.format(100*(index)/num_url),end = '   ')
        index += 1
    time_end = time.perf_counter()
    print('\n单线程运行用时%ds'%(time_end-time_start))
    #单线程运行用时153s
# Out:
# http://www.doutula.com/photo/list/?page=1
# http://www.doutula.com/photo/list/?page=2
# http://www.doutula.com/photo/list/?page=3
# http://www.doutula.com/photo/list/?page=4
# url: http://www.doutula.com/photo/list/?page=4 连接失败
# http://www.doutula.com/photo/list/?page=5
# http://www.doutula.com/photo/list/?page=6
# http://www.doutula.com/photo/list/?page=7
# http://www.doutula.com/photo/list/?page=8
# url: http://www.doutula.com/photo/list/?page=8 连接失败
# http://www.doutula.com/photo/list/?page=9
# http://www.doutula.com/photo/list/?page=10
# 任务已完成:2.4%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-0dd458c53419> in <module>
#      45         os.chdir(r'C:\Users\hc_lzp\爬虫\imags')
#      46         with open(file_name,'wb') as f:
# ---> 47             f.write(requests.get(url,headers = headers ,timeout=5).content)
#      48         print('\r任务已完成:{:.1f}%'.format(100*(index)/num_url),end = '   ')
#      49         index += 1
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     179
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#     183
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
# 使用生产者与消费者模式多线程下载表情包：
#Queue是python标准库中的线程安全的队列（FIFO）实现,提供了一个适用于多线程编程的先进先出的数据结构，即队列，
#用来在生产者和消费者线程之间的信息传递
import requests 
from fake_useragent import UserAgent
from lxml import etree
import os
import re
import time
from queue import Queue
import threading

# 生产者用来解析页面，获得图片的url和name
class Producter(threading.Thread):
    headers = {"User-Agent": UserAgent().chrome}
    def __init__(self,page_queue,img_queue,*args,**kwargs):
        super(Producter,self).__init__(*args,**kwargs)
        #python3中可以简写为super().__init__(*args,**kwargs)
        self.page_queue = page_queue
        self.img_queue = img_queue
    def get_html_text(self,url,headers,timeout=5):
        try:
            resp = requests.get(url,headers=headers,timeout=timeout)
            resp.raise_for_status
           # resp.encoding = 'UTF-8' 
            return resp.text
        except:
            return ''
    def xpathParser(self,text):
        html = etree.HTML(text)
        photo_xpath = '//*[@id="pic-detail"]/div/div[3]/div[2]/ul/li/div/div/a/img/@data-original'
        name_xpath = '//*[@id="pic-detail"]/div/div[3]/div[2]/ul/li/div/div/a/img/@alt'
        img_url_list = html.xpath(photo_xpath)
        img_name_list = html.xpath(name_xpath)
        for url,name in zip(img_url_list,img_name_list):
            ext = os.path.splitext(url)[1].split('!')[0]
            row_file_name = name + ext
            # 去除Windows操作系统中规定文件名中不能含有的符号
            file_name = re.sub(r'[\\/:\*\?"<>\|]','',row_file_name)
            self.img_queue.put((url,file_name))  #用元组储存，便于分包   
    def run(self):
        while True:
            if self.page_queue.empty():
                break
            url = self.page_queue.get()
            text = self.get_html_text(url,self.headers)
            if text == '':
                print('url: {} 连接失败'.format(url))
            else:
                self.xpathParser(text)        

# 消费者用来下载图片
class Consumer(threading.Thread):
    headers = {"User-Agent": UserAgent().chrome}
    def __init__(self,page_queue,img_queue,*args,**kwargs):
        super(Consumer,self).__init__(*args,**kwargs)
        #python3中可以简写为super().__init__(*args,**kwargs)
        self.page_queue = page_queue
        self.img_queue = img_queue           
    def run(self):
        while True:
            if self.img_queue.empty() and self.page_queue.empty():
                return
            img_url,file_name = self.img_queue.get()
            with open('C:\\Users\\hc_lzp\爬虫\\imags\\'+file_name,'wb') as f:
                f.write(requests.get(img_url,headers = self.headers ,timeout=5).content)
            print(file_name+'  下载完成！')
def main():       
    page_queue = Queue(100)  #储存页面所在的url,这里的大小至少要大于爬取的页面大小
    img_queue = Queue(1000)  
    row_url = 'http://www.doutula.com/photo/list/?page={}'
    for i in range(0,10): 
        url = row_url.format(i+1)
        page_queue.put(url)
    for x in range(5):
        t = Producter(page_queue,img_queue)
        t.start()   
    for x in range(20):
        t = Consumer(page_queue,img_queue)
        t.start()    
 
main()
# 好像3s完成
# Out:
# 小旺仔强.jpg  下载完成！
# 你管这个玩意叫针？.png  下载完成！
# 天空一声巨响，本萌宝闪亮登场.jpg  下载完成！
# 林子大了，什么鸟都有.jpg  下载完成！你们正常几小时？.jpg  下载完成！想看喷奶是吗？.jpg  下载完成！先吃燕麦.jpg  下载完成！楼上工头叫你去搬砖别装文化人了.jpg  下载完成！
# 像极了爱情.jpg  下载完成！
#
#
# 国际手势.jpg  下载完成！
# 新来的交保护费，我两个手下可不是什么好人收保护费处.jpg  下载完成！现在的孩子都是.jpg  下载完成！死了.jpg  下载完成！
# 嗝儿.jpg  下载完成！
# 喝一口牛奶内.jpg  下载完成！
#
#
# 咕噜.jpg  下载完成！小旺怎么了？.jpg  下载完成！
# 为了逗爸爸笑你仿佛十分卖力！.jpg  下载完成！
#
#
#
# 在？借我3999.jpg  下载完成！等下我就打的萌萌新鸡巴脱.jpg  下载完成！
#
# 傻B.jpg  下载完成！
# 没关系鸭，你不是抓到了我吗.jpg  下载完成！
# 让我看看是哪个秃头女孩还不睡觉.jpg  下载完成！
# 贱货死吧.jpg  下载完成！
# 楼上.jpg  下载完成！
# 帅哥们都加我一下，我是群里最会嘤嘤嘤的.jpg  下载完成！可好吃了.jpg  下载完成！
#
# 别想太多，吃包辣条.jpg  下载完成！
# 你要的黄图小小年纪不学好，下次不许看了！.jpg  下载完成！一个个虎了吧叽地.jpg  下载完成！强行达成共识.jpg  下载完成！
#
#
# 逐渐起了杀心.jpg  下载完成！
# 同志，伏特加.jpg  下载完成！
# 难过.jpg  下载完成！
# 突然苏维埃.jpg  下载完成！苏维埃式问候.jpg  下载完成！
#
# 我觉得你抠.gif  下载完成！
# 谢谢老板.gif  下载完成！
# 我先睡了，你们继续修仙吧.gif  下载完成！
# 我的内心一片污秽甚至自动打码了.gif  下载完成！
# 谢谢老板.gif  下载完成！
# 红包红包红包红包.gif  下载完成！
# 好像看到了什么，不得了的东西.gif  下载完成！
# 忍住不能笑！！.gif  下载完成！
# 运气王发红包.gif  下载完成！
# 不不不那是你.gif  下载完成！
# 高手，看不透.png  下载完成！
# 假的我不相信你.gif  下载完成！
# 无聊啊.gif  下载完成！
# 狗蛋于长大了，爸爸很欣慰.gif  下载完成！
# 在座的都是大佬.gif  下载完成！
# 大半夜不碎觉吵JB吵.gif  下载完成！
# 老司机无所畏惧.gif  下载完成！
# 不知不觉又搬完了一年的砖，大家干杯！新年再接再历！好！干杯！的.jpg  下载完成！
# 祝大佬新春快乐.jpg  下载完成！
# 捂脸.gif  下载完成！
# 狗蛋在士里不敢说话.jpg  下载完成！
# 群主快发红包.gif  下载完成！

# %%
# 多线程下载百思不得其解的段子和链接，并保存为csv文件
import requests
import csv
import threading
from lxml import etree
from queue import Queue
from fake_useragent import UserAgent
import re
import time

LOCK = threading.Lock()  #防止读数据出错

class Producter(threading.Thread):
    headers = {"User-Agent": UserAgent().chrome}
    def __init__(self,url_queue,csv_queue,*args,**kargs):
        super().__init__(*args,**kargs)
        self.url_queue = url_queue
        self.csv_queue = csv_queue
    def get_html_text(self,url,headers,timeout=5):
        try:
            resp = requests.get(url,headers=headers,timeout=timeout)
            resp.raise_for_status
           # resp.encoding = 'UTF-8' 
            return resp.text
        except:
            return ''
    def xpathParser(self,text):
        html = etree.HTML(text)
        title_xpath = '//span[@class="article-title"]/a[@target="_blank"]/text()'
        content_xpath = '//div[@class="summary-text"]'
        title_list = html.xpath(title_xpath)
        content_list = html.xpath(content_xpath)
        for every_title,every_content in zip(title_list,content_list):
            content = re.sub('[\t]','',''.join(every_content.xpath('.//text()')))
            self.csv_queue.put((every_title,content))
            print((every_title,content))
    def run(self):
        while True:
            if self.url_queue.empty():
                break
            url = self.url_queue.get()
            text = self.get_html_text(url,self.headers,timeout=5)
            if text == '':
                print('url: {} 连接失败'.format(url))
            else:
                self.xpathParser(text)        
class Consumer(threading.Thread):
    def __init__(self,url_queue,csv_queue,*args,**kargs):
        super().__init__(*args,**kargs)
        self.url_queue = url_queue
        self.csv_queue = csv_queue
    def run(self):
        print('消费者来了')
        while True:
            print('消费者csv_queue:   {}'.format(self.csv_queue.qsize()))
            print('消费者url_queue:   {}'.format(self.url_queue.qsize()))
            if self.url_queue.empty() and self.csv_queue.empty():  #如果爬取的页面较少，这里就要注意哦
                return  #这里写成return 直接跳出程序
            LOCK.acquire()
            with open('笑话2.csv','a',encoding='utf-8',newline='') as f:
                writer = csv.writer(f)
               # print(self.csv_queue.get())
                writer.writerow(self.csv_queue.get())
            LOCK.release()
                
def main():
    url_queue = Queue(100)
    csv_queue = Queue(500)
    row_url = 'http://xiaohua.zol.com.cn/new/{}.html'

    for i in range(1,101):
        url = row_url.format(i)
        url_queue.put(url)
    for x in range(5):
        t = Producter(url_queue,csv_queue)
        t.start()   
   # time.sleep(5)   
    for x in range(10):
        t = Consumer(url_queue,csv_queue)
        t.start()   
        
main()
# Out:
# 消费者来了消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了
# 消费者csv_queue:   0
#
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了消费者url_queue:   95
#
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
# 消费者来了消费者来了
# 消费者csv_queue:   0
# 消费者url_queue:   95
#
# 消费者csv_queue:   0
# 消费者url_queue:   95
# ('萌宝都好笑,非常惹人爱', '\r\n\r\n\r\n1、晚上做的菜饭，隔壁萌娃一看说：伯伯你做的菜饭一看就不好吃。\r\n我说：可好吃了。\r\n他说：我不信，除非你让尝一碗，我才知道。\r\n一小碗吃了，我问：好吃吗？\r\n他说：还行，要想我夸你做的好吃，你得再给我来一碗。\r\n我。。。\r\n\r\n\r\n2、小的时候喜欢逮蜜蜂，每当逮着一个，就在蜜蜂肚子上扎个洞，就使劲吸，你别说，肚子里的蜂蜜，还真好吃！\r\n等以后，慢慢长大上了，上学后，老师告诉我，那是绿豆蝇。。。\r\n\r\n\r\n3、昨晚去超市给儿子买用来包平安果的苹果，去之前问他买几个，他说两个就够了。......')
# 消费者csv_queue:   0('雷死子女的搞笑爸妈', '\r\n\r\n\r\n1、陪老婆回娘家，恰逢小姨子23岁生日，我发了23块钱红包，她说我抠门。\r\n后来丈母娘在厨房对小姨子说：“以后不要这样说你姐夫，他抠门是因为没钱，而他没钱是因为娶了你姐埃”\r\n\r\n\r\n2、我说喜欢了一个很优秀的男生，但是感觉没机会。\r\n我妈说你怕啥，你虽然差劲，但能有机会接触到这么好的人，说明他命中注定有此一劫。\r\n\r\n\r\n3、小时候家里没暖气，我问父亲咱家啥时候能暖和？\r\n父亲说：“等一等，等到夏天就暖和了。” 从此我就知道，幸福是等来的。\r\n\r\n\r\n4、妈妈：“傻闺女，你为什么这么疯狂的迷恋郭小四！ ”......')
# 消费者url_queue:   95
#
# ('爆逗男女,有笑很无语!', '\r\n\r\n\r\n1、很多男人对美女没有抵抗力，而我不一样，我根本不想抵抗。但美女想抵抗。\r\n\r\n\r\n2、早知道伤心总是难免的你又何苦一往情深。。。妹的，我一往情深的时候真没想到伤心还成了难免的了呢。\r\n\r\n\r\n3、女孩犯错了，男孩安慰她：“人非圣贤孰能无过。”\r\n女孩：“什么？我在你眼里不是神仙？？”\r\n\r\n\r\n4、男孩不道歉，女孩说：“连个对不起都没有？”\r\n男孩道歉，女孩说：“对不起有什么用？”\r\n\r\n\r\n5、女：“爱我你就抱抱我。”\r\n男：“爱你是真的，抱不动你也是真的。”\r\n\r\n\r\n6、干活时伤了手，女友知道后跑来医院看我，心疼的抹着眼泪怪我干活不小心。......')
# ('爆逗,看的清楚,还说的明白', '\r\n\r\n\r\n1、有钱的时候钱不算钱，没钱的时候人不是人。\r\n\r\n\r\n2、比看自己照片更可怕的是听自己的录音。\r\n\r\n\r\n3、往桌面上放文件和往椅子上扔衣服是一样的。\r\n\r\n\r\n4、对你说“高处不胜寒”的人正是会把别人从“高处”推下去的人。\r\n\r\n\r\n5、当代人生活节奏太快了，还没进卫生间就开始解裤子。\r\n\r\n\r\n6、佛系人生的依次四个阶段：接受父母是平庸的人，接受自己是平庸的人，接受配偶是平庸的人，接受孩子是平庸的人。\r\n\r\n\r\n7、不好看的人很耗电，因为一张图要修一小时......')
# ('爆笑,都憨厚的很呀!', '\r\n\r\n\r\n1、老太太在河边用鱼做放生。一个大叔上前劝说道：“大娘，你以后别放生这种草鱼了！你可以放生那种罗非鱼！ ”\r\n老太太纳闷道：“放生鱼还有讲究？”\r\n大叔憨厚的说道：“草鱼刺多，我媳妇吃不惯！ ”\r\n\r\n\r\n2、我姐：“算来算去，我银行卡余额就是少了两百块。”\r\n我笑了笑说：“可能是姐夫拿了。”\r\n她说：“不可能，他要是拿了会有短信和记录。”\r\n于是我给她演示一遍，拿她手机给我发了一块钱，然后删除短信、交易记录等等蛛丝马迹。。。\r\n她忽然骂我：“看来你也不是什么好东西。”\r\n\r\n\r\n3、我让女友坐下，说有重要的事要告诉她：“亲爱的，你不是总说自己好喜欢好喜欢一家三个人快乐的生活么？关于这一点嘛……”......')
# ('逗的他(她)们满脸黑线头', '说有那么几个人在踢足球，分红蓝两方，红队守门员说：“我是铁门，你们球进不来１这时，蓝队守门员冷笑一声，“我是钢门１。。。')
# 消费者csv_queue:   4('冷到弱智的黑段子', '“师傅，教我分身术吧。”“首先，你要有把电锯。。。”')
# 消费者url_queue:   95
#
# ('0度笑话,刚从冰箱里拿出来', '“三弟，有人说我们兄弟数学不好１“四哥，他们凭什么这么说？”')
# ('童言无忌', '最近看新闻总是看到生二胎的，最后却丢了性命，感觉异常恐怖。一天家里小孩央求给他生个弟弟或者妹妹。就把看到的新闻给他讲了一遍：“宝贝，你看新闻上说了，这个阿姨为了生弟弟妹妹，都死掉了。”宝贝马上问：“为什么你生我的时候没有死？”我和宝贝他爸尽无言以对。')
# ('爷爷好可爱', '我爷爷被一只蜘蛛咬了, 他看起来非常沮丧, 于是我准备给他去拿些药膏, 可是就在我走出房间之前, 我听到爷爷说:"到了这个年纪, 实在是承担不了做蜘蛛侠的责任阿."')
# ('2+2=？', '一天，上数学课，老师说：“加法的意义，就是把两个数合起来。比方说1+1等于2。”第二天，老师问小明：“ 2+2等于几？”小明说：“老师，我们昨天没学2+2，只学了1+1。”')
# ('久仰久仰', '有个脚痒患者或者是脚气患者去看医生，见到医生时突然脚就痒起来，就说脚痒脚痒，医生听成了久仰久仰，便客气地回答道哪里哪里，患者指着脚说这里这里')
# ('“打”', '在公交车上的时候，一个爸爸在对他儿子说：“都那么大了还打不过你妈妈，我十二岁就能打过你奶奶了！ ”旁边一哥们冲那爸爸吼到：“有你这么教育孩子的吗？会不会当爹啊！ ”那男的愣了愣，说：“我说的是羽毛球！ ”那哥们顿时一脸想死的冲动啊！')
# 消费者csv_queue:   10('我买单', 'A和B在饭店吃饭，吃完以后谁都不想结帐，只好用掷骰子猜单双的方法决定。A：“好了，骰子盖在桌子上了！ ”B：“买定离手，你先来。”A：“我买双，你呢？”B：“我买单！ ”A：“去吧。”')
#
# 消费者url_queue:   95
# ('玉米粒穿婚纱', '两个相爱的玉米粒决定结婚，可是婚礼时找不到新娘了，新郎问一直跟在身边的一个爆米花，爆米花害羞地说：讨厌，人家穿的是婚纱！')
# ('餐前祷告', '一天，你遇到狮子，故作镇定，用可怕的眼神瞪狮子。突然狮子双手合十并跪了下来，你得意地说：知道厉害了吧！少顷,狮子幽幽地道：祷告完毕，可以用餐了。')
# ('这波爸妈,能笑出泪花', '\r\n\r\n\r\n1、我问妈妈：“如果时间倒流，你还会选择嫁给爸爸吗?”\r\n妈妈说道：“还会的!”\r\n我很感动，虽然妈妈经常抱怨爸爸的小毛病，但还是深爱着爸爸的埃\r\n然后妈妈对我说：“你怎么不问问，如果时间倒流，我还会生你吗？”\r\n\r\n\r\n2、接到老妈深夜来电“你弟两口子吵架了！快给你弟媳妇儿打电话劝劝……”\r\n“妈，这种事还是假装不知道的好吧？人家小两口自己会解决的……”\r\n“好！等你们两口子吵架的时候我也假装不知道！ ”\r\n\r\n\r\n3、一大龄男青年，一直找不到女朋友！......')
# ('爆笑二货,想手撕他们', '\r\n\r\n\r\n1、我发圈：再也不想单身了，多么希望有个人可以和我一起吃饭的时候抢菜吃，白天抢电脑，晚上抢被子！\r\n损友回：早上抢刮胡刀。。。\r\n\r\n\r\n2、一同事对另外一同事说：嗨，兄弟当初你在天上当天蓬元帅的时候能不能干过二郎神啊？\r\n另一同事沉默了会说到：能不能干过二郎神没试过，但肯定能干过二郎神身边的你。\r\n\r\n\r\n3、我以为若干年后，我们再次见面,你我都开着车，在一个豪华的大酒店聚会。\r\n然而现实却是：我在工地搬砖，你却和你老公来工地挑户型！我次奥！\r\n\r\n\r\n4、车站，一男帮一位姑娘抬了抬行里，他问：美女你多大了？......')
# 消费者csv_queue:   14
# 消费者url_queue:   95
# ('逗段说男女,有点小讽刺', '\r\n\r\n\r\n1、女人彪脏话这事儿，长得漂亮就是真性情，长得丑就是没家教。\r\n\r\n\r\n2、女人总是怀疑男人不爱她，而男人怀疑女人是不是又在怀疑他不爱她。\r\n\r\n\r\n3、女孩第一次感到人生幸福大概是小时候爸爸背着你满世界溜达，女孩第一次感到人生绝望大概是结婚后老公背着你满世界溜达。\r\n\r\n\r\n4、都说女人好色，其实女人好色只有五种：黄色的黄金、粉色iPhone、白色的宝马、黑色的貂皮衣、彩色的RMB！\r\n\r\n\r\n5、人都是有执念的，有时候你觉得你非常喜欢一个人，喜欢得死去活来，非Ta不可，那只是因为你还没有得到Ta。。。\r\n\r\n\r\n6、在不喜欢的人面前家里是有门禁的，家教是很严的，外宿是不存在的。......')
# ('百味生活,一定要幽默', '\r\n\r\n\r\n1、6000多首歌从KTV下架，对我完全没有影响，对于我来说，只要果盘不下架就行。\r\n\r\n\r\n2、你的钱虽然不是大风刮来的，但是像被大风刮走的。\r\n\r\n\r\n3、掉头发是因为太久没对象，你的头发认为你出家了，所以开始脱落。\r\n\r\n\r\n4、穷人这个词太伤自尊，现在叫价格敏感型消费者！\r\n\r\n\r\n5、只要人人都能用批评他人的标准来要求自己，世界将变成美好的人间。\r\n\r\n\r\n6、称呼面前加个素字都是假的，比如素肉、素鸡、素三鲜、还有素颜。\r\n\r\n\r\n7、上学时看到“不良”二字，想到的是混混。工作后看到“不良”，想到的是呆账，退休后看到“不良”，想到的是药物反应。\r\n\r\n\r\n8、耳垂有什么用？在外面玩不回家，你妈、你老婆找到你时，带你回家专用。\r\n\r\n\r\n9、不努力，你背井离乡干嘛，当卧底啊？！\r\n\r\n\r\n10、中国式婚姻——凑合！......')
# 消费者csv_queue:   15
# 消费者url_queue:   94
# 消费者csv_queue:   14
# 消费者url_queue:   94
# 消费者csv_queue:   13
# 消费者url_queue:   94
# 消费者csv_queue:   12
# 消费者url_queue:   94
# 消费者csv_queue:   11
# 消费者url_queue:   94
# 消费者csv_queue:   10
# 消费者url_queue:   94
# ('新的一年从爆笑开始!', '\r\n\r\n\r\n1、班花毕业后，自己开始创业，开了一家店每天起早贪黑，暗恋她的我到她店里，闲聊时对她说，何必这么累，你一句话，我养你。\r\n班花眼含泪花的说：“我之所以这么努力，就是怕落在你这种人手里。”\r\n\r\n\r\n2、刚看到朋友碗里半碗黑黑的，我问：“咖啡还是芝麻糊啊？”\r\n朋友看起来很憔悴答：“土也不够吃了。。。我在土里加了水，兑成泥粥喝喝！ ”\r\n我去。。。\r\n\r\n\r\n3、“枸杞爱上菊花，眼镜就亮了。”\r\n“骗人，枸杞塞到菊花里，眼晴也没感觉亮埃”\r\n“别人眼前会一亮啊！！！ ”\r\n\r\n\r\n4、“除了吃喝你还会什么？”......')
# ('用笑段和快乐的春节说再见吧', '\r\n\r\n\r\n1、不是这年没有味道了，而是现在过年时，最快乐的人不是你！\r\n\r\n\r\n2、鳄鱼咬到猎物时不会撕扯，只会360°翻转身体，所以被鳄鱼咬到不用担心，只要跟着鳄鱼一起翻转且速度够快的话，还可以把鳄鱼头给拧下来。\r\n\r\n\r\n3、现在的年轻人，应该多向家里要钱，不然这些钱留在家人手里，迟早要被保健品和XX币骗光的！\r\n\r\n\r\n4、好看的皮囊经不起扫黄打非\r\n，有趣的灵魂又涉嫌账号违规\r\n。真TM悲催！\r\n\r\n\r\n5、人的一生中至少要有两次冲动，一次为奋不顾身的爱情，一次为说走就走的旅行。人的一生中也至少要有两次后悔，一次为奋不顾身的爱情而导致怀孕，一次为说走就走的旅行而赶上春运。\r\n\r\n\r\n6、老师提醒你：寒假千万条，作业第一条。过节不学习，开学两行泪！\r\n\r\n\r\n7、既然有“劝酒”文化，可不可以同样“劝书”呢？......')
# ('春节里一些搞笑的事儿', '1、闺蜜的化妆品店里，有个顾客听了闺蜜介绍的一款化妆品，有点动心，看来是要买一套。\r\n我在一边赶紧助攻：这款化妆品真的不错，你看我就是用的这款。\r\n那个顾客看了看我，摇着头走了。\r\n\xa0\r\n2、一觉醒来头重脚轻，晕的厉害。\r\n“妈，我头疼，好像感冒了。。。”\r\n“快快快，把药吃了！ ”老妈火速端水拿药“等会儿你表姐她们要来咱家玩，还指望你做饭呢！ ”\r\n\xa0\r\n3、去吃涮锅，要了一个清汤锅。吃了一会，觉得嘴唇麻麻的！\r\n问服务员，是不是锅上错了，这么麻，吃不了。......')
# 消费者csv_queue:   12('二货硬是把情人节过成了损货节', '\r\n\r\n\r\n1、曾经有一份真挚的爱放在我面前，那是今天情人节在电影院，我前面一对情侣深情拥吻，感觉爱得很真挚。\r\n\r\n\r\n2、“今天情人节，有人陪我去看电影吗？”\r\n“你请客吗？你请客我和我对象陪你去！ ”\r\n“。。。”\r\n\r\n\r\n3、“来，说点情人之间才会说的话，假装过个情人节！ ”\r\n“分手吧！ ”\r\n\r\n\r\n4、感情不好的情侣，趁今天情人节赶紧甩掉对方，这样以后对方过情人节都会想起被甩，让它膈应一辈子！\r\n\r\n\r\n5、昨晚梦到月老，问他：明天就是情人节了，连个情人都没有，你咋牵的红线呀？你为什么不给我一个情人？”......')
#
# 消费者url_queue:   94
# ('年后的笑段还是这么春节', '\r\n\r\n\r\n1、自从年前我结婚之后我妈再也没有对我唠叨过，每天除了看电视剧就是跳广场舞，气色明显比以前好太多了，这就是人们常说的“娶了媳妇，旺了娘”吧！\r\n\r\n\r\n2、过年在家，老妈嫌弃我爹洗衣服不干净，我爹则反过来嫌我妈浪费水。于是降大任于我，我成功集两者之长：既费水又洗得不干净。\r\n\r\n\r\n3、春节过后，老婆问儿子：你是喜欢去奶奶家啊，还是去姥姥家？\r\n我在旁劝道：他这么点小孩，不要问他这种问题？\r\n老婆横了我一眼：那你来答？\r\n\r\n\r\n4、过年时我听到楼上大姐歇斯底里地大叫：不许叫外卖！你这两天的胃容量是属于妈妈的！养儿千日，用儿吃几天剩菜还不是应该的吗？\r\n\r\n\r\n5、今天是春节上班第一天，......')
# ('是幽默的深刻,还是深刻的幽默?', '\r\n\r\n\r\n1、岁月磨平了你的棱角，其实就是你被生活盘了。\r\n\r\n\r\n2、你不是真的胖，只是女娲捏土造你的时候土用多了。\r\n\r\n\r\n3、当员工好累埃平时做牛做马，到年底了还要表演节目给领导逗乐子。\r\n\r\n\r\n4、人生，总有不得不走的回头路：比如出门上班走到楼下才发现没带手机。\r\n\r\n\r\n5、为什么经常看见妻子吊打小三，却很少看见丈夫痛殴奸夫？因为小三一般比妻子瘦弱，而奸夫一般比较丈夫健硕。\r\n\r\n\r\n6、怕开宝马的同学认出没戴头盔骑摩托车的你，真的想多了。人家工作、购物、居注......')
# ('爆冷,冻僵你滴笑脸', '\r\n\r\n\r\n1、医院里，一孕妇难产，医生灵机一动，给她服用了益生菌。\r\n\r\n\r\n2、300斤的某女没看到她老公躺在沙发上，一屁股把他坐死了。法律并没有追究她的责任，因为法不责重。\r\n\r\n\r\n3、两个老人去养老院。。。\r\n70岁的老人进去了，90岁老人没进去。\r\n工作人员：“对不起，大爷，我们不接受儿女健在的老人。您的资料显示，你有一个儿子。”\r\n90岁老人：“操，刚刚进去的就是我儿子！ ”\r\n\r\n\r\n4、和哥们去一个经常去的小饭馆吃饭，因为经常去所以特别熟！吃完饭结账时104块钱，我和老板说：打个把零抹了吧？......')
# ('戏谑男女,难道说的就是你?', '\r\n\r\n\r\n1、爱情就是一场考试，而你连准考证都没有。\r\n\r\n\r\n2、男生一般都鼓励女生去做美甲，这样轻易不舍得挠他！\r\n\r\n\r\n3、女孩承认错误也没有想象得那么难，比如“我错在不该认识你！ ”很容易就能说出口。\r\n\r\n\r\n4、如果网购是种病，那一定是一种。。。一种妇科病！\r\n\r\n\r\n5、原单，形容你原来就是单身。尾单，意思是你朋友全都脱单了，就你没有。\r\n\r\n\r\n6、在小鲜肉的围攻下，老男人本来就不吃香，现在呢？老男人彻底成了危险品，没钱的白嫖，有钱的送你坐牢。\r\n\r\n......')
# ('逗B们可笑极了', '\r\n\r\n\r\n1、“谁这条命，也不是大风刮来的。”\r\n“蒲公英是。”\r\n\r\n\r\n2、买了个灯泡，问老板为什么不亮？\r\n老板说：这是限亮版。\r\n\r\n\r\n3、你有那种明知道是错的还是会去做的事吗？\r\n考试！！！！！！\r\n\r\n\r\n4、如何形容一个菜鸟停车入位？\r\n我就蹭蹭，我不进去。\r\n\r\n\r\n5、9点半是一个非常适合起床的时间，谈不上赖床，也不算早起。洗漱完毕，吃个简单早饭，也才十点。此时距离中午还剩两个小时，可以做一些重要的事，比如睡个回笼觉。\r\n\r\n\r\n6、“你这只猪”听着像骂人，但换成“你这只佩奇”就像是在夸人可爱了。\r\n\r\n\r\n7、在床上吃烧烤被我妈看到了，我妈说：跟你说过多少遍了！不要动不动就把床搬到院子里！\r\n\r\n\r\n8、最近发现自己心理有些问题，年纪轻轻的，居然对年轻姑娘失去了兴趣，反而对少妇有着深深的迷恋。......')
# ('笑的憨憨的,气的饱饱的', '\r\n\r\n\r\n1、我：“我和王思聪一起掉到了水里，你先救谁？”\r\n女友：“你没资格和王思聪一起掉水里。”\r\n我。。。\r\n\r\n\r\n2、我：那个男人你到底爱他什么？\r\n闺蜜：我就是爱他怎么办？\r\n我：你说一个三十多岁的男人，整天不工作，还伸手找父母要钱，这样的男人你到底看上他啥了？\r\n闺蜜：你不懂，富二代的生活就是这样的。\r\n我。。。\r\n\r\n\r\n3、那天帮女友家干活，一不小心，额头嗑了一下，血涌了出来。。。\r\n女友吓坏了，捧着我的脸，眼泪汪汪地从嘴里掏出个口香糖粘在了伤口上。。。\r\n\r\n\r\n4、同事接到电话说老婆在医院快生了，我开车送他到医院。......')
# ('实话实话实在好笑', '\r\n\r\n\r\n1、在校花费吃不消，回家精神受不了——部分大学生现状。\r\n\r\n\r\n2、胖起来这件事情，肚子和腿最有发言权了，只有胸好像一个局外人，跟它一点关系都没有。\r\n\r\n\r\n3、进入职场后我学习到了两件乍看起来矛盾但却可以并存的事情：第一，要做个能够让人信任的人；第二，别信任任何人\r\n\r\n\r\n5、如何让这个世界变得美好？答：把你自己变得更美好。\r\n\r\n\r\n6、满口黄腔多心地善良，沉默君子定多加堤防！\r\n\r\n\r\n7、当我对抗生活时，生活说：“胆子不小啊？”然后把我按在地上疯狂摩擦。......')
# ('爆囧,玩笑开的有点过头了?!', '\r\n1、年底了，打电话给客户要工程款，说好这礼拜给钱的。\r\n下午接到客户电话让我到公司去，我开心的去了。\r\n到他办公室他跟我说：年底没有钱了，货款没收到，过了年再跟我清账，让你过来就是当面跟你打个招呼。电话里说不礼貌。\r\n我。。。\r\n\r\n\r\n2、和闺蜜一起看宫 斗剧，我就问闺蜜：你看，以我的智商，在皇宫里能活几集？\r\n闺蜜却说：就你这身材、这颜值，还想进宫？！\r\n我。。。\r\n\r\n\r\n3、今天开着车在路上被奥迪蹭了，年轻的奥迪司机下来甩给我200块钱，说一个破大众我还是赔的起的。......')
# ('天儿冷,笑话也冷呢!', '\r\n\r\n\r\n1、“大爷，我现场采访您一下，您这样晨跑锻炼坚持几年了？”\r\n“姑娘别挡道！我尿急！ ”\r\n\r\n\r\n2、“请问你是做什么工作的？”\r\n“哦。我的工作是杀僵尸。”\r\n“嗯？可是这个世界上没有僵尸啊！ ”\r\n“你以为它们是怎么没有的？”\r\n\r\n\r\n3、中午去买菜，感觉都不太新鲜了。\r\n老板：早上刚到的，都新鲜的。\r\n我：这菜看着就蔫蔫的啊？！\r\n老板：从早上到现在，它以为没人要自己了，这不垂头丧气么！\r\n我。。。\r\n\r\n\r\n4、我问他：你今天怎么没上班儿啊？......')
# ('爆糗,家里炸窝啦!', '\r\n\r\n\r\n1、恋爱时，我爸一直不同意我跟老公的恋情，直到老公第一次进门拜访，脱了鞋子。。。\r\n我爸憋了口气说：小伙子，就冲这个味跟我闺女是一样的，人你领走吧！\r\n\r\n\r\n2、老妈看我整天在家里愁眉苦脸，过来问我：“儿子，你咋这么忧虑啊？”\r\n我叹了口气，说：“还不是找女朋友的事啊，愁死我了！ ”\r\n老妈安慰我说：“没事的，看开点吧。”\r\n我摇摇头说：“妈，你不懂，我是不想和我爸一个下场！ ”\r\n\r\n\r\n3、我：“妈，我想买条金毛。”\r\n妈：“什么东西？”\r\n我：“金毛猎犬，小狗八百一只。”......')
# 消费者csv_queue:   22('爆逗,这些夫妻可以拿搞笑奖', '\r\n\r\n\r\n1、晚上下班回来发现客厅灯泡坏了，买好正在换的时候，媳妇回来进门看到就说：天都黑了，能看到吗？我把灯给你打开。\r\n\r\n\r\n2、去年结婚纪念日带媳妇去买了项链，手链，花了一万多，感觉有些肉疼。\r\n今年媳妇让我送给她五千字的情书，我觉得还是花点钱实在些。\r\n\r\n\r\n3、老婆办了健身卡计划减肥，健身一个月后，她欣喜地对我说：“你看你看，我的皮带以前只能扣在第一个孔，今天可以扣到第二个孔了。”\r\n我看了看，说：“嗯，你的手劲练大了。”\r\n\r\n\r\n4、那天，老婆买了一个塑料锤放在客厅。说我气到她，她就用塑料锤砸我。我觉得不痛不痒的，随她。......')
#
# 消费者url_queue:   94
# ('幽默妙侃,有很多笑段等着你', '\r\n1、你并不孤单，有很多困难在等着你。\r\n\r\n\r\n2、初墨，多么诗意的名字啊，可她姓熊。。。\r\n\r\n\r\n3、为什么长得好看的姑娘有钱花？因为好看的姑娘节约了修图时间，而时间就是金钱。\r\n\r\n\r\n4、我们只是宇宙中毫不起眼的一坨蛋白质，当然有些人是一坨脂肪。\r\n\r\n\r\n5、当一束光照进房间里，房间里的肮脏龌龊被显现，这束光便有了罪！\r\n\r\n\r\n6、当一个姑娘深情的跟你说，我不在乎你有没有钱，我就是喜欢你，想和你在一起。\r\n这时候你一定要好好想一想，好好看一看自己，是不是自己做了些什么事情，让姑娘误以为你很有钱。\r\n\r\n\r\n7、女人分两种，让你头大的，让你头疼的，没一个让你好过的。......')
# ('新的一年从爆笑夫妻开始', '\r\n\r\n\r\n1、二货老婆上厕所玩手机，一玩还就没完没了。\r\n早上起来，提着裤子等半天，批评她她还不高兴。。。说：“上厕所不玩手机，难道要玩屎啊？”\r\n\r\n\r\n2、和老公回家吃饭，老爸掌厨老妈打下手，两个人不时的交头接耳，窃窃私语！\r\n我在后面羡慕的看着一把年纪还恩爱的爸妈对老公说：我们以后老了也要像这样好不好？说不完的情话！\r\n老公看了看我犹豫的说：我刚听到他们在说你都嫁人了，回来也不知道搭把手，越来越懒了，也不知道我怎么受得了你的。。。\r\n\r\n\r\n3、老公：老婆，据调查，大多数女的都没有达到高潮，你老实回答我，你有没有达到高潮？......')
# ('笑看生活,酸甜苦辣都是乐', '\r\n\r\n\r\n1、如果努力就有收获，那还要运气干什么？\r\n\r\n\r\n2、活了20多年，还不如一件毛衣会放电！\r\n\r\n\r\n3、成年人一天解锁手机60次，不找你就是不想找你。\r\n\r\n\r\n4、跟鼻子高的女朋友接吻真的好麻烦，还要先找一个鼻子高的女朋友才行。\r\n\r\n\r\n5、无理取闹的人，会发现挡路的人越来越少，因为他的路越走越窄。\r\n\r\n\r\n6、办了健身卡又各种偷懒不健身？不要为此感到内疚，毕竟你领了工资不也没认真工作吗？！\r\n\r\n\r\n7、妈妈从小就教育我，自己一个人能解决的就不要麻烦别......')
# ('夫妻耍点小幽默,日子更快乐', '\r\n\r\n\r\n1、闺蜜他老公最近特别喜欢带闺蜜去宾馆，今天在一起我问他：哎，你最近怎么老和丽丽去宾馆啊？不怕浪费钱啊？\r\n结果他悄悄的和我说：没有钱换人，只好花点小钱换房了！\r\n\r\n\r\n2、老婆：“这瓶维生素丸，你带给你的女秘书吧。”\r\n老公：“为什么？”\r\n老婆：“昨天她落了不少头发在你的衣服上呢。”\r\n\r\n\r\n3、老公：“这菜。。。我吃出了叛徒的味道。”\r\n老婆：“怎么说？”\r\n老公：“油大。”\r\n\r\n\r\n4、做好了饭菜，刚刚摆上桌，就感到屎意来袭，就赶紧去厕所里便便。。。......')
# ('几段职场的爆笑尬事', '\r\n\r\n\r\n1、本人总经理秘书，前几天老总老板娘还有几个同事私下吃饭，老总喝得高兴，看着我说：小兰啊，你该减肥了，公司食堂好，你也要控制埃\r\n没等我开口老板娘说话了，人家不胖，刚刚好，小兰别听他的。\r\n老总一激动说，还不胖？那天把我大腿差点坐折了。。。\r\n老板娘，你听我解释，那天是我绊了一跤刚好坐老总身上了，不是你想的那样的。。。\r\n\r\n\r\n2、领导：今天的讲话就说到这里，有什么异议吗？\r\n我：有！\r\n领导看着我，问：你有什么异议？！\r\n我：领导您刚才的讲话对我们有很大的意义！\r\n\r\n\r\n3、公司张经理和李经理为了副总的位置斗得很厉害。......')
# 消费者csv_queue:   27
# 消费者url_queue:   93
# 消费者csv_queue:   26
# 消费者url_queue:   93
# 消费者csv_queue:   25
# 消费者url_queue:   93
# 消费者csv_queue:   24
# 消费者url_queue:   93
# 消费者csv_queue:   23
# 消费者url_queue:   93
# 消费者csv_queue:   22
# 消费者url_queue:   93
# 消费者csv_queue:   21
# 消费者url_queue:   93
# 消费者csv_queue:   20
# 消费者url_queue:   93
# 消费者csv_queue:   19
# 消费者url_queue:   93
# 消费者csv_queue:   18('爆囧,老年人也可以笑死人', '\r\n\r\n\r\n1、老奶奶打的，到达目的地后计价器显示20元，下车时老奶奶只给10元。\r\n司机：“你怎么只付10元呢？”\r\n老奶奶：“你不也座车了，一人一半嘛！ ”\r\n\r\n\r\n2、老头躺在床上干咳几声，幽幽地看着养了10多年的黑猫，说：“要是我死了，就没人喂你吃你最爱吃的小鱼干了。”\r\n黑猫从电视机上跳下，叹了口气，钻出门外。\r\n社区诊所里，老中医看了看大黑猫，拿起急诊箱苦笑道：“是你啊，又是你主人叫你来的吧？他就不能老老实实自己打电话叫我去吗？”\r\n\r\n\r\n3、老张的女儿快出嫁了，这几天老张的媳妇不知道怎么了，三天两头对老张发脾气，又是罚跪搓衣板，又是罚睡地板，又是搜私房钱老张问：“老婆，这几天你怎么了？你让我把这辈子的家暴都尝了一遍”......')
# 消费者url_queue:   93
#
# ('爆逗,伤的越深,笑的越狠', '\r\n\r\n\r\n1、我暗恋一妹子，想找机会表白，今天她一闺蜜跟我透露说这个妹子很向往找一个暖男做男友，细想一下我的为人处事，备感自信，我认真问她闺蜜：“你看我算不算暖男？”\r\n她说“暖男还是要看脸的，你顶多算个热狗！\r\n\r\n\r\n2、鼓足勇气给我心仪的女生表白后，女生冷冷地：“我喜欢有钱的男朋友！ ”\r\n在我错愕间，她缓缓地继续说道：“我知道你现在心里认为我很物质，是个坏女孩。其实恰恰相反，喜欢有钱的男朋友只能说明我非常努力，敢于挑战人生。”\r\n我下意识问道：“为什么？”\r\n女生目光看向窗外：“因为有钱的男朋友很花心啊！ ”\r\n\r\n\r\n3、我回家路上买了一只烤鸭坐电梯回家。中途上来一个牵着狗的美女。狗一进来就冲着烤鸭咬了一口。......')
# ('讽刺与挖苦的精选逗段', '\r\n\r\n\r\n1、别看胖子们平时害怕露肉暴露自己，称体重时可是脱得精光呢，能少一两是一两。\r\n\r\n\r\n2、所谓单人床和双人床，跟宽度没关系，枕边有人就是双人床，单身睡再大的床也是单人床。\r\n\r\n\r\n3、那个让你在最高兴的时候一想起就会立即变得难过，又或者在最悲伤的时候一想起就会扬起微笑的人，叫做遗憾。\r\n\r\n\r\n4、比你优秀的人比你更努力，这个你可以接受。但是比你优秀的人，比你更不努力，你就懵了，凭啥呀？就凭你蠢。\r\n\r\n\r\n5、希望现在的男演员们，能分清妖孽和娘炮、风流和猥琐、英......')
# ('爆囧,气得一脸黑线头', '\r\n\r\n\r\n1、昨天鼓起勇气，打电话向女神表白，TM居然被拒绝了。。。\r\n其实我觉得吧，如果她不喜欢我，请直接告诉我，没必要撒谎骗我说我长得丑啊！！！\r\n\r\n\r\n2、我：“要不要减肥啊？我有过胖的老婆，还没有过瘦的老婆。”\r\n老婆看了我一眼说：“你也没有过更胖的老婆呀？！ ”\r\n气得我一脸黑线头。。。\r\n\r\n\r\n3、老婆刚生二胎，哥们聚会，我去不了，就回短信：老二太小了，来不了。\r\n不明情况的哥们打电话给我说：“来吧，就吃饭唱歌，不碍事。。。”\r\n我。。。\r\n\r\n\r\n4、我：“你发现没，为什么猫咪越胖越惹女人喜爱，人长得胖就不讨女人爱？”......')
# 消费者csv_queue:   21('忍俊不禁,童萌最搞笑', '\r\n\r\n\r\n1、带女儿去打针，她爬凳子上对护士说：“姐姐，姐姐你轻点，要是把我打疼了，明天我就叫你阿姨，后天叫你奶奶。。。”\r\n\r\n\r\n2、给小侄子灌输三字经教育，我念道：“昔孟母，择邻处，子不学，断机杼。。。”\r\n小侄子插话道：“孟子他妈下手也忒狠了！孩子不学习揍两下还不行，犯得着狠到把脊柱都给打断了吗？？”\r\n我。。。\r\n\r\n\r\n3、外甥问我女儿几岁上的幼儿园？\r\n女儿说五岁啊！\r\n然后她说我也五岁上的幼儿园，你为什么比我大两岁呢？\r\n\r\n\r\n4、幼儿园的阿姨和孩子们聊天：“你们谁知道，为什么饭前必须洗手？”......')
# ('幽默冷段笑的欢', '\r\n\r\n\r\n1、过夜的叫酒店，喝酒的却叫夜店。\r\n\r\n\r\n2、眼镜盒不是新眼镜的家，是旧眼镜的棺材。\r\n\r\n\r\n3、打呼噜的人能在自己的呼噜声中睡着也太不公平了。\r\n\r\n\r\n4、友谊其实很简单，就是在自己吃到好吃的食物的时候想着对方，然后拍下来发给他。\r\n\r\n\r\n5、“怂B”这个词听着就很低端，建议换成“生活磨平了我的棱角”，听着好像真的战斗过一样。\r\n\r\n\r\n6、古人挺乐观的其实，有点闲工夫都琢磨着怎么长生不老，现代人忙完一天的事静下心来瘫在床上心里只有四个字：不想活了。\r\n\r\n\r\n7、“钱”有一种不那么市侩的说法，我们代称它叫“上进心”、“有肩膀”、“有品味”。\r\n\r\n\r\n8、冬天，一个农民发现一条褐色的蛇冻僵了，于是他把放到自己怀里暖着。......')
#
# 消费者url_queue:   93
# ('乐翻,家里闹出一打笑风波', '\r\n1、我下班刚进门，老妈高兴的说：闺女，来，替我打两把，换换手气。我去菜市场给你买鱼去，妈知道你最爱吃鱼啦，说完急匆匆的走了。。。\r\n刚打完两把，两个阿姨也要回家做饭。一个阿姨说：你妈欠我160！\r\n另一个阿姨：欠我60！\r\n对面阿姨：欠我100。。。\r\n妈呀，这鱼价格可不便宜啊！！！\r\n\r\n\r\n2、全家出去吃饭偶遇老公的前女友一家人。\r\n我忍不住偷偷指着老公前女友问儿子：“你说那个阿姨和你妈我谁比较漂亮？”\r\n儿子瞄了她一眼，淡定地说：“你俩谁漂亮我说了不算，但是我敢肯定我爸要是娶了她肯定生不出像我这么帅气又聪明的儿子！ ”......')
# ('爆囧,醉人的爸妈你有没有?', '\r\n\r\n\r\n1、老妈看到我头上有几根白头发，心疼的摸了摸，说：玩手机挺费脑子的吧，这么年轻都长白头发了。\r\n\r\n\r\n2、老爸：“你该结婚了！ ”\r\n我：“结婚就一定幸福吗？我有个同学都二婚了，何必呢。”\r\n老爸：“如果结婚不好，人家能结两次？”\r\n我。。。\r\n\r\n\r\n3、中秋节快到了，打电话给老妈，想让她给我寄点鸭蛋黄的月饼，老妈应允。。。\r\n今天又给老妈打电话，问她月饼帮我买了没？\r\n老妈：“没呢，再等几天，中秋过完了给你买，那时候处理月饼便宜！ ”\r\n我。。。\r\n\r\n\r\n4、今天一个精神科医生朋友给我说：很多时候遇到被父母拖过来做心理咨询的小孩，一聊天，这孩子挺正常的啊！？再和父母一聊天，这不典型的偏执型人格吗？......')
# ('二缺同学让你笑个够', '\r\n\r\n\r\n1、学渣同学刚开学见面就给我分享经验，说：不写暑假作业只是挨一顿揍，但是却快乐了整个假期，值！\r\n\r\n\r\n2、小学时语文课本的古诗最让我头疼，因为完全不懂。\r\n后来上中学才发现，语文的古诗简直是最好懂的了，更变态的是其他科目里的古诗：什么“奇变偶不变，符号看象限”，什么“氢氦锂铍硼，碳氮氧氟氖”，什么“ 哈吉塔巴阿富汗，印尼不丹缅老南”，什么“染色一复胞二裂，数目减半同源别”，都什么玩意啊！\r\n\r\n\r\n3、一同学特爱面子，快放暑假时，兜里快没钱了。他去地摊买了个十八元的特丑旅行包。拿包回学校时，一同学见了说：你包好丑。......')
# ('爆逗二货,郁闷的不轻', '\r\n\r\n\r\n1、给暗恋的女神发消息：“我下个月就要死了，你能来参加我的葬礼吗？”\r\n她回复：“下个月没空，这个月有空，你能早点死吗？”\r\n\r\n\r\n2、“你吃不吃萝卜？”\r\n“不吃。”\r\n“白菜？”\r\n“不吃。”\r\n“南瓜？”\r\n“不吃。”\r\n。。。\r\n“你什么都不吃啊，好挑食哦。”\r\n“啊？我不挑食啊！我什么肉都吃的！ ”\r\n\r\n\r\n3、我深情地望着女朋友说道：“我的眼里只有你。”\r\n女友一把揪住了我的耳朵，我疼得直叫，忙问她：“我说错什么话了吗？”......')
# ('生活妙侃,发发牢骚吐吐槽', '\r\n\r\n\r\n1、没人喜欢听从聪明的穷人，而都愿意相信有钱的笨蛋。\r\n\r\n\r\n2、不知从什么时候开始，还钱成了检验友谊的唯一标准。。。\r\n\r\n\r\n3、上大学要钱，找工作要大学学历，赚钱就得找工作，谁TM发明了这个完美的系统？！\r\n\r\n\r\n4、发现电子书和纸质书一个区别，纸质书有回忆。想以前读的什么东西，纸质的，能大概记起当时在哪儿，什么心情，甚至什么光线。电子书就只记得大拇指在扒拉。\r\n\r\n\r\n5、购买便宜的商品，是消费心态的升级吗？不一定。有钱人买便宜货才是心态升级，你买则是勒紧裤......')
# ('爆囧,把你笑成眯眯眼', '\r\n\r\n\r\n1、朋友收到了女友寄来的礼物，打开一看是顶LV的帽子，他若有所思的问我：“LV用中文怎么说？”\r\n我弱弱地答：“绿。。。”\r\n\r\n\r\n2、昏黄的路灯下，坐在长椅上的女孩捂着脸嘤嘤哭泣路过的他见状心生怜惜，走到她面前问道：“你还好吧？”\r\n女孩仰起哭得梨花带雨的脸，习惯性回答说：“我。。。我没事！ ”\r\n他借着路灯看清了女孩的长相，于是接到：“哦，没事那我先走了！ ”\r\n\r\n\r\n3、室友叫我跟他出去溜溜，我玩游戏不愿意去，室友说你不去别后悔，我本来打算介绍对象给你认识的。......')
# ('乐侃生活的幽默逗段', '\r\n\r\n\r\n1、吃东西容易减肥难，所以要先吃了再说，因为先易后难。\r\n\r\n\r\n2、什么叫缺乏独立思考？就是别人问你晚上吃什么，你说随便。\r\n\r\n\r\n3、随着年龄的增长，你不断升级并解锁超市中的新区域。\r\n\r\n\r\n4、水可以这么喝：茉莉蜜茶喝半瓶加半瓶水，就成了茉莉花茶；再喝再加就成了茉莉清茶；再喝再加，就成了茉莉花茶无糖版；再喝再加，就成了农夫山泉有点甜；再喝再加，纯净水。\r\n\r\n\r\n5、一直以为芝麻是从草莓身上来的，但是黑芝麻怎么来的，这件事困惑了我许多年，如今我看见了火龙果。\r\n\r\n\r\n6、适度自私有益身心健康，过分懂事体贴反而一文不值。具体参考富察皇后。\r\n\r\n\r\n7、一边说着减肥，一边点着夜宵；一边说着早睡，一边看剧熬夜；一边说着省钱，一边打开花呗；一边说着孤独，一边拒绝亲近。。。这就是我们！\r\n\r\n\r\n8、一个人这一方面有缺点，另一方面会很优秀！比如一个瞎子，听觉就会很灵敏！......')
# 消费者csv_queue:   29('笑迹斑斑,乐事不断的小俩口', '\r\n\r\n\r\n1、老公在地毯上捡了一块钱说：这啥家庭啊？巨款都不要了。。\r\n\r\n\r\n2、和老婆冷战，为了缓和气氛，我：你看这样冤冤相报何时了呢？\r\n老婆白了我一眼：很简单！以后我骂你，你不许还口；我打你，你不许还手。\r\n我。。。\r\n\r\n\r\n3、我：“今天你怎么没戴项链。”\r\n老婆直接了当的说：“掉了！ ”\r\n看到我要发飙，她立刻又飞快的说道，“你可别想着凶我，半个月前就掉了，开始还有点怕你骂我，现在不怕了！来来来，我们先讨论一下这半个月你有没有关心我，然后再说丢项链的事儿！ ”......')
#
# 消费者url_queue:   93
# ('爆囧,二货青年尬事多', '\r\n\r\n\r\n1、我追一漂亮女孩儿，晚上我给她发信息：我喜欢上你了，怎么办？\r\n她回了我五个字：憋住，暗恋着！\r\n\r\n\r\n2、“可以问你一个问题吗？”\r\n“你说。”\r\n“如果一个人他长得不好看，又没钱，还秃头，那么这个人不就是你吗？”\r\n“滚。”\r\n\r\n\r\n3、最近几天，突然人品爆发，我们这小区的几个媒婆，争着给我介绍女朋友，让我受宠若惊！！！\r\n后来听一个媒婆跟老妈聊天，说：我们几个约定，谁要是能给你儿子介绍成女朋友，谁就是我们这小区第一媒婆。。。\r\n我。。。\r\n\r\n\r\n4、前段时间，一妹子的签名这样写：我爱你，不是因为你开兰博基尼，住海边别墅，而是那天阳光正好，你穿着一件我喜欢的白衬衫，对，爱情就这么简单。......')
# ('爆损,变着法儿玩套路', '\r\n\r\n\r\n1、女友：“峨眉山的峨怎么写？”\r\n我：“山我”\r\n啪！！！\r\n我。。。\r\n\r\n\r\n2、去桑拿，我正躺在沙发床上休息，一服务员过来问：“您是要单号还是要双号的技师呀？”\r\n我：“有啥区别？”\r\n经理神秘一笑，说：“单号就是单纯的按按，双号嘛。。。你懂的！ ”\r\n我怒道：“净说些让人听不懂的话！那个。。。我要12号吧！ ”\r\n\r\n\r\n3、今天回到公司，老板娘对我说：“瞧你，皮肤好得像婴儿似的，用的护肤品挺贵吧？”\r\n我很开心的说：“没有啦，我只用一些普通的洗面奶和乳霜。”......')
# ('能笑喷人的夫妻都是好夫妻', '\r\n\r\n\r\n1、早上起床，感觉像吹了一夜的凉风，人昏昏沉沉有点感冒。\r\n可我明明记得没开风扇啊？\r\n这时又一阵凉风吹来，低头一看，是老婆张嘴呼吸呢！\r\n\r\n\r\n2、打麻将三缺一，只好让从不玩麻将的媳妇儿顶个位置。\r\n结果，媳妇儿风卷残云，把我们哥仨都卷了！\r\n我惊奇的问：“媳妇儿！你什么时候会打麻将了？”\r\n她说：“实不相瞒，八年前我就是用麻将牌把你从你前女友手里赢过来的！ ”\r\n我。。。\r\n\r\n\r\n3、饭后，老公突然拿起我的手机玩了起来，我：“干嘛玩我手机？”......')
# ('一小打幽默情感逗语', '\r\n\r\n\r\n1、你嘴上总说一个人就很开心，但是你打游戏时却喜欢找几个人一起打。\r\n\r\n\r\n2、占有和征服有什么区别？答：男人都想做女人的第一个男人，这是占有，而女人只想成为男人的最后一个女人，这叫征服。\r\n\r\n\r\n3、老说自己老婆是败家娘们什么的男人，都是在炫耀：一是炫有老婆，二是炫有钱，三是炫又有老婆又有钱。\r\n\r\n\r\n4、被异性朋友突然拉黑，不用觉得莫名其妙，不是Ta讨厌你了，而是Ta曾经考虑过你，只是Ta现在撒网成功了。\r\n\r\n\r\n5、两个女人和一个男人逛街(猜一三字人名)：买买提......')
# ('思路一变,笑声一片', '\r\n\r\n\r\n1、打哈欠是我们身体的20%剩余电量警告。\r\n\r\n\r\n2、既然欲速则不达、而好事又多磨，由此可见拖延症应该得到更多的尊重。\r\n\r\n\r\n3、冬天的被窝怎么暖都不热，夏天的凉席一趟就热。\r\n\r\n\r\n4、你之所以要努力工作，不是因为这份工作没你不行，而是因为这份工作没你也行。\r\n\r\n\r\n5、你要注意身体啊，心里已经很变态了，身体一定要健康啊！\r\n\r\n\r\n6、夏天的女孩子都喜欢穿着超短裙出来散步，但是夏天的风就像一个急不可耐的男人，不停地掀着她们裙子。\r\n\r\n\r\n7、年轻......')消费者csv_queue:   34
# ('爆囧,丢人丢大发了', '\r\n\r\n\r\n1、第一次租房时和房东面谈。\r\n房东说：每个月一千元租金，交一年的话呢就是一万。\r\n请原谅我理工科的头脑，我马上发现了错误。我反问道：一年一万，一个月不应该是八百多吗？\r\n房东听了觉得我说的很有道理，羞愧的改成了一年一万二。\r\n\r\n\r\n2、去逛商场，看到一个专营店的衣服很漂亮，就把外套一脱交给服务员开始各种试穿，试穿了很多衣服一看价格还是觉得算了，回头问服务员：我的外套呢？\r\n服务员找了很久，呆呆地看着我说：刚才客人太多，好像。。。好像是被我卖了。。。\r\n\r\n\r\n3、电梯里，小屁孩看了我一眼：“叔叔好！叔叔你真帅！ ”......')
#
# 消费者url_queue:   92
# 消费者csv_queue:   34
# 消费者url_queue:   92
# 消费者csv_queue:   33
# 消费者url_queue:   92
# 消费者csv_queue:   32
# 消费者url_queue:   92
# 消费者csv_queue:   31
# 消费者url_queue:   92
# 消费者csv_queue:   30
# 消费者url_queue:   92
# 消费者csv_queue:   29
# 消费者url_queue:   92
# 消费者csv_queue:   28
# 消费者url_queue:   92
# ('逗B的逗,笑喷的笑', '\r\n\r\n\r\n1、今天在医院排队，前面一女的在登记。\r\n医生问姓名，女的说张逗逗。\r\n医生问了两次是哪个逗？\r\n女的说不清，突然在不远处传来一个声音：“逗B的逗！ ”\r\n顿时场面就控制不住了。。。\r\n\r\n\r\n2、“国内有些人有了钱就一副人生导师的嘴脸，到处演讲，以为自己放个屁都是金玉良言，这样的人为什么不是我爸爸？”\r\n“因为都比你年轻！ ”\r\n\r\n\r\n3、今天第一次坐商务舱，特别兴奋，感觉空姐的眼神都跟平时不一样了。。。\r\n果然，我刚坐一会儿就有空姐主动来搭讪：“先生，您坐错了，经济舱在后面。”\r\n\r\n\r\n4、办公室里，女同事阴沉着脸，我问：“怎么了？怎么不高兴啊？”......')
# ('带娃带出爆笑一大波', '\r\n\r\n\r\n1、野炊烧烤炖羊肉，大家说柴火铁锅炖羊肉香，起灶生火，让六岁的小侄女找点细细的木柴来引火，结果小家伙给我一包牙签。。。\r\n\r\n\r\n2、我躺在小屋午睡，小侄子扑上来跟我闹，结果脚崴了哭个不停。。。\r\n都问我咋回事？我实在是不好意思说是一脚踩我胸上了。。。\r\n\r\n\r\n3、朋友送我一只小黑猫，我怕它孤单，又买了一只小白猫。\r\n恰好，侄子要写一篇小动物的作文，嫂子带侄子来观察猫。\r\n侄子从下午一直看到晚上两只猫休息。\r\n侄子对嫂子说：妈，经我观察，这两只猫就像你和我爸，白天一碰面就掐，晚上却挤在一起睡觉！\r\n\r\n\r\n4、带侄子逛街，见天桥有一乞丐，就给了侄子一块钱，意思培养一下他的爱心。......')
# 消费者csv_queue:   29
# 消费者url_queue:   92
# ('搞笑熊孩子,将来一定有出息', '\r\n\r\n\r\n1、姐和姐夫吵架了，姐哭得很伤心想从外甥那寻求点安慰：我和你爸要离婚了，你不安慰下妈妈么？\r\n外甥：我应该安慰爸爸，爸爸那么丑，离婚了上哪儿找媳妇啊！\r\n\r\n\r\n2、儿子向老婆要零花钱，未果，儿子急眼了，朝着她喊：妈你是最漂亮的了，说话又温柔，腰还很细。。。\r\n最后，老婆烦不胜烦，掏钱递给他了，谁知小家伙说：算了，骗来的钱还是不要了！\r\n\r\n\r\n3、小时候，我用纸做了一条蛇，我妈最怕蛇了，我把它放在房门口，我妈出来了，它吓子一跳，本来妈是出来上厕所的，现在不用上了。。。\r\n\r\n\r\n4、侄女3岁，她爸爸给她五块钱让她去家门口小超市买橙汁，......')
# ('醉人的爸妈很能惹人笑呀!', '\r\n\r\n\r\n1、我妈每次给我爸气受，他都气的摔蜂窝煤，我不解问他：爸，你怎么不摔别的？\r\n老爸：废话，别的摔坏了不得买吗？煤球摔坏了我加点水，再托成模还能烧！\r\n我：厉害呀爸，我家烧天然气，没有煤球，我摔什么合适啊？\r\n我爸说，你甩自己大嘴巴！\r\n\r\n\r\n2、蛋糕就剩两块了，儿子问：“妈妈，我可以吃两块吗？”\r\n老婆说：“当然可以！ ”拿起一块放在嘴里，用刀把剩下的一块切成两块，对他说：“你的两块蛋糕，吃吧！ ”\r\n\r\n\r\n3、急性肠胃炎被送去医院，我痛的死去活来，我爸赶来看我，一脸焦急地跟我说：“这医院怎么一个WIFI都连不上！ ”\r\n\r\n\r\n4、全家5口开车回家，我坐在后排中间。......')
# ('爆笑,无损不乐,无二不欢', '\r\n\r\n\r\n1、吃完饭跟女朋友闲聊：“亲爱的，那些失足的小姐姐们，都说金盆洗手以后，就找个老实人嫁了，你说什么样的男人才算老实人？”\r\n她愣了一下，若有所思地说：“其实也没什么界定，我觉得你就挺老实的呀。”\r\n哈哈哈~没想到女朋友对我的为人评价还挺高的。。。\r\n\r\n\r\n2、我问女友：你不是另结新欢了？\r\n女友：你这么问我，我肯定说不是啊，如果你换个问法，我肯定说是。\r\n我：怎么问？\r\n女友：你问我是不是对没钱没相貌没潜力的你没有半点留恋了，我肯定说是。\r\n我。。。\r\n\r\n\r\n3、雨一直下，走路鞋都湿了，自嘲说：还好，我没穿袜子。......')
# ('爆逗二货猛戳你笑点儿', '\r\n\r\n\r\n1、给暗恋的女生连续发了好几天短信，她都没回复，今天她终于回复了一条：TD。\r\n我问：“啥意思？”\r\n她说：“退订。”\r\n\r\n\r\n2、女友：“我一天没吃饭了。”\r\n男友：“6666666。”\r\n\r\n\r\n3、女“你一定会遇到更好的人。”\r\n男：“我连你这种普通货色都留不住，遇到更好的人有啥用？”\r\n\r\n\r\n4、七夕节那天，心情特别压抑，一个人去公园散心。\r\n突然旁边一美女拍了拍我的肩膀，笑了笑说：“帅哥，你是不是单身啊？”\r\n突如其来的甜蜜让我有些不知所措，我羞红了脸，支支吾吾地说道：是啊！......')
# ('有逗B的七夕情人节最好笑', '\r\n\r\n\r\n1、七夕节，笑友们有什么好礼物推荐吗？十万以下的十块左右的。\r\n\r\n\r\n2、七夕大酬宾：收旧对象，用不着的对象，用旧对象 、破对象、用不着的对象换盆，换大铝盆，换各种盆，任您挑眩\r\n\r\n\r\n3、七夕节，某单身逗B接受采访：“请问你单身这么多年是凭借怎样的信念活下来的？”\r\n“快乐。”\r\n“是什么样的快乐呢？”\r\n“看情侣分手快乐。”\r\n\r\n\r\n4、今天晚上在路上看到某人开车带的不是自己的那口子。\r\n我不点名是谁，你好自为之。给我转200块钱这事就算过去了！......')
# ('幽默谈感情,谈出点笑容', '\r\n\r\n\r\n1、女友生气了，赶紧哄。男友生气了，让他冷静冷静。\r\n\r\n\r\n2、喜欢一个人是藏不住的，就算躲在衣柜里，还是会被他老公发现。\r\n\r\n\r\n3、想要忘记一段感情，方法永远只有一个：时间和新欢。要是时间和新欢也不能让你忘记一段感情，原因只有一个：时间不够长，新欢不够好。\r\n\r\n\r\n4、你女朋友莫名其妙不开心了，别说‘又怎么了’，而是说‘怎么了怎么了’，效果立马不一样。\r\n\r\n\r\n5、人生真是容易产生错觉，领导赞许的目光可能是你身后的同事，异性的青睐的目光可能也只是正常的社交礼仪，也行，真正喜欢你的就是在家等待喂食的猫狗。\r\n\r\n\r\n6、岁月的确让男人成熟，以前媳妇喊我大名，我还傻乎乎的过去看看，现在都知道跑了。\r\n\r\n\r\n7、女神说：“来！让我靠一下。”......')
# ('爆汗,有老婆压力更大呀!', '\r\n\r\n\r\n1、洗澡时，耳朵不小心里进了水，耳洞里湿湿得难受，出来后我歪着脑袋向下倒。\r\n老公看到了，皱着眉头拉我躺在沙发上，用棉签帮我沾干，还不无担忧地说：媳妇儿，耳朵进水了我能帮你弄干净，但你脑子里进的水，我是真没办法了！\r\n\r\n\r\n2、正上班呢，老婆给我发了两张穿着不同衣服的自拍照，还问我那张漂亮。\r\n作为过来人，我明白说那张漂亮都不对，所以回答说：都挺漂亮的。\r\n老婆回到：你也这么觉得吗？那我两件都买了。\r\n\r\n\r\n3、老婆：老公，今天同学聚会，我真不想去。......')
# ('逗段侃男女,侃的心花怒放的', '\r\n\r\n\r\n1、请管好你的嘴。因为我会随时亲你。\r\n我有一个超能力，超级喜欢你......')
# 消费者csv_queue:   36
# 消费者url_queue:   92
考上学校然后不想去上课，疯狂面试然后不想上班，买房子然后没钱吃饭，谈恋爱然后想自由，努力生小孩然后发愁怎么养。。。总之就是，不断给自己挖坑。\r\n\r\n\r\n5、有钱舒服安逸的日子会让人意志消沉，可是没钱的日子会让人生不如死。。。\r\n\r\n\r\n6、最喜爱的武侠人物是柯镇恶，不管对方武功多高都上，总是大叫一声：无耻之徒拿命来。......')消费者csv_queue:   40
# ('又爆家糗,舍小家笑大家', '\r\n\r\n\r\n1、在我刚毕业没找到工作之际，我爸朋友圈分享的前两篇文章分别是《该不该给儿子买房》和《孩子，没人欠你的》\r\n\r\n\r\n2、每次回家，我妈都会给我弄条鱼吃，可我根本不爱吃鱼啊，又不好明说，怕负了老妈一番心意，于是旁敲侧击问我爹：“咋每次都弄鱼呢，我又不爱吃！ ”\r\n我爹冷笑一声：“还看不明白吗，嫌你多鱼呢！ ”\r\n\r\n\r\n3、正吃饭，老妈来了，说吃过饭了，就坐在沙发上看电视，媳妇陪着坐沙发上，边看电视边冲我说：老公，就这一个碗了，你快点吃，吃完给我吃！\r\n老妈：你们都困难成这样了，家里就一个碗？跑厨房一看，碗池里泡着的一池子碗。。。\r\n\r\n\r\n4、男友第一次来家里吃饭，他前脚刚刚走，弟弟就对我抱怨：姐，你咋找个这么丑的男盆友啊？我还没开腔，老爸慢条斯理地开口了：这小伙子丑是丑点，但是你没感觉到是你姐占了便宜吗？？\r\n\r\n\r\n5、小时候和爸妈去市里玩，我哭着闹着要买新衣服，我妈就打我，我爸拦着不让打。......')
# 消费者url_queue:   92
#
# ('校园笑段,都不怎么喜欢学习', '\r\n\r\n\r\n1、有些话，只说给懂的人听，比如英语听力考试。\r\n\r\n\r\n2、学霸以成绩为动力，学渣以作业为动力，我就厉害了，以上课睡觉为动力！\r\n\r\n\r\n3、不敢看银行账户余额数字的是成年人，不敢看成绩单数字的是学生，两个都不敢看的是大学生。\r\n\r\n\r\n4、上高中和堂姐在一个学校，堂姐长的很漂亮，每天都和堂姐一起骑车上下学，然而没过多长时间，我的车胎就天天被人扎，那时候我才理解了红颜祸水的真正含义。。。\r\n\r\n\r\n5、宿舍里，室友乐呵呵的问我：“动手术和动感情有什么共同点？”......')
# ('胡喷瞎侃的幽默逗语', '\r\n\r\n\r\n1、爱上你不是我的错，都是你胸大腰细惹的祸。\r\n\r\n\r\n2、长辈们认为吃饭时玩手机是坏习惯，其实换个角度看，我们是玩手机时不忘吃饭，怎么样，是不是显得很会照顾自己呢?\r\n\r\n\r\n3、有一种最棒的感觉就是：手机充满了电，我终于可以拔掉充电器，滚去床的另外一边了。\r\n\r\n\r\n4、男人最喜欢的女人类型：大长腿，大眼睛，皮肤光滑油腻，脑子里都是墨水，还粘人-------其实大海里面有很多这种动物，Ta们的名字叫---乌贼！\r\n\r\n\r\n5、敢于直面惨淡的人生，敢于面对淋漓的鲜血，就是不敢面对......')
# ('爆二男女,都是逗B货', '\r\n\r\n\r\n1、“做我女朋友吧，行还是不行？只许回答一个字！ ”\r\n“滚。”\r\n\r\n\r\n2、本人屌丝一个，今天发个朋友圈：我要努力赚钱，要不以后怎么养活我众多的女人！\r\n俺心中的女神回我：买个打气筒就可以了！\r\n\r\n\r\n3、相亲。我跟妹子说：坦白跟你讲，我这个人啊，都是见人说人话，见鬼说鬼话的。\r\n妹子：那你想跟我聊什么？\r\n我：聊钟馗。\r\n妹子。。。\r\n\r\n\r\n4、女友下班回来对我说：“亲爱的，今天晚饭你做吧，我手头还有点工作。”\xa0\r\n“我不做。”......')
# ('父母很醉人,年龄就是度数', '\r\n\r\n\r\n1、晚上洗澡时发现忘了带内裤。把浴室门打开一条缝，让妈帮我拿来。\r\n我妈说：下了几天暴雨了，没干呢！\r\n我急着穿呢就让她去帮我买一条，过了半天，终于听到我妈说：买好了！\r\n我一听那赶紧给我拿进来呀。\r\n结果她说：还没发货！\r\n\r\n\r\n2、小时侯有次村边玩，偷了个西瓜吃，结果刚吃了一半被看瓜的发现了。\r\n瓜主人找我爸，说我偷瓜，老爸拿起棍子就要抽，瓜主人看到我哭了，就拦住我爸：算了，小孩子嘛！\r\n等瓜主人走了，我爸掏出五毛钱：去，买包糖吃，不打你得赔一块！\r\n\r\n\r\n3、第一次去见女友父母，吃饭的时候她妈问：“现在消费那么高，小伙子每个月能挣多少钱呀？”......')
# 消费者csv_queue:   44
# 消费者url_queue:   91
# 消费者csv_queue:   43
# 消费者url_queue:   91
# 消费者csv_queue:   42
# 消费者url_queue:   91
# 消费者csv_queue:   41
# 消费者url_queue:   91
# 消费者csv_queue:   40
# 消费者url_queue:   91
# 消费者csv_queue:   39
# 消费者url_queue:   91
# 消费者csv_queue:   38
# 消费者url_queue:   91
# 消费者csv_queue:   37
# 消费者url_queue:   91
# 消费者csv_queue:   36
# 消费者url_queue:   91
# ('爆糗,不怕你笑话', '\r\n\r\n\r\n1、我在餐饮店送外卖，有个客户总喜欢点我们店的外卖。\r\n有一次，他问：“你们外卖是不贵，但你们厨师是老厨师吧？”\r\n我：“是啊，经验丰富，做的菜是一流的，味道与众不同，您也吃得出这个是老厨师的手艺？”\r\n客户：“老厨师的手艺我吃不出来，但我总是能吃出白头发来！ ”\r\n我。。。\r\n\r\n\r\n2、本人近视，那天看到前面一女拎着一个白色打底青色流苏状点缀的包包特别好看，感觉好配自己买的湖水绿的连衣裙，遂跑上去说：“你的包包好好看，哪儿买的？”\r\n结果走近一看：是一个塑料袋里面挂了两把大葱。\r\n\r\n\r\n3、“今天我生日，竟然意外地听到了生日快乐歌！ ”......')
# ('笑话连篇聊男女', '\r\n1、万圣节还用化妆？直接本色演出就好了，穷鬼一个啊！\r\n\r\n\r\n2、男生单身久了看谁都是貂蝉，女生单身久了看谁都是渣男！\r\n\r\n\r\n3、10个漂亮女孩儿，一半觉得自己不好看，另一半觉得自己不够好看；10个男生，一半觉得自己帅，另一半觉得自己帅得要命。\r\n\r\n\r\n4、如果你的自拍怎么都找不到好看的角度，那你就必须认识到你本人比照片好看这件事了。\r\n\r\n\r\n5、这年头要女人干啥？！男
# 消费者url_queue:   91
#
# ('父母和子女的幽默大作战', '\r\n1、今天老婆对女儿说：以后考试放松心情好好考，考不好没关系，我和你爸爸还年轻，打死你还能生。\r\n\r\n\r\n2、今天哥哥带着三岁的小侄女去放风筝，风很大把线刮断了，风筝飞走了，两人只好很郁闷的回家。\r\n\r\n\r\n回家的路上小侄女问：爸爸风筝飞走了，那它什么时候飞回来？\r\n\r\n\r\n哥哥回答到：下个月你妈妈给我零花钱的时候它就会回来啦！\r\n\r\n\r\n小侄女坚定的点了点头。。。\r\n\r\n\r\n3、“哥，你是不是怕老婆啊？”\r......')
# ('哭瞎孩子的爆逗爸妈', '\r\n\r\n\r\n1、“爸，在么”\xa0\r\n“不在”\xa0\r\n“不要钱”\xa0\r\n“在”\r\n\r\n\r\n2、我妈打电话给我说：儿子！快来医院，你姐姐要生了！！\r\n我说：好 ！顺便问了一下是男还是女。\xa0\r\n我妈说：现在还不知道，所以不知道你是当叔叔还是阿姨。。。\r\n\r\n\r\n3、流鼻血了，房间没纸，赶紧跑出客厅说：“妈，我流鼻血了！ ”\r\n我妈：“快拿手接住，我刚拖的地！ ”\r\n我。。。\r\n\r\n\r\n4、正上班呢，老爸打来电话，他说天气变凉了，要我多注意。。。......')
# ('二货的尬事笑翻天', '\r\n\r\n\r\n1、前些天嗓子病了，不能发声，领导却让我参加合唱比赛，给我说充个数就行。\r\n我感觉这样不好，就积极治疗，赶在比赛前治好了。\r\n结果比赛失利，领导一声叹息的道：“你怎么偏偏赶在这时候嗓子好了呢？”\r\n\r\n\r\n2、半夜，路过按摩店，里面老板娘就朝我喊：老板，进来坐坐。\r\n我对她说：“要钱么”。\r\n然后她怒了说：“你见过世上免费的按摩店么？”\r\n然后我破口大骂她：“你TM见过这么晚才下班的老板么？”\r\n\r\n\r\n3、上厕所忘带纸了，发微信跟同事求救，这货没一会就进来了，让我发十块钱红包给她，不然就不给我纸！......')
# ('参透男女,搞笑如有神', '\r\n\r\n\r\n1、感觉到对方喜欢你，十有八九是错觉。感觉到对方讨厌你，十有八九就是真的啦～\r\n\r\n\r\n2、男人说“我喝醉了”，女生该回复什么？\r\n翻身的机会终于到了：多喝点热水。\r\n\r\n\r\n3、不接电话，不回信息，却发朋友圈的人。这种行为应该列入国家刑法，涉嫌故意伤害罪。\r\n\r\n\r\n4、以前读中学时经常听到一句话：金钱如粪土！读大学时经常听到一句话：一朵鲜花插在牛粪上！等到毕业工作后才知道这两句话得合在一起理解。\r\n\r\n\r\n5、追女孩要怎么样厚脸皮？追女孩别人不要脸，你就不要命～别人可以在她楼下等她，你就吊根绳子到她家阳台～\r\n\r\n\r\n6、爱和喜欢是同义词么？爱一朵花就为她浇水。喜欢一朵花就把她摘下来。......')
# ('爆逗夫妻,家是搞笑的港湾', '\r\n\r\n\r\n1、老公：家是温暖的港湾。\r\n老婆：我靠，老娘真的是第一次见到6个平方的港湾啊!\xa0\r\n老公：也是，太小了，装你这200多斤的大船很吃力啊！\r\n老婆。。。\r\n\r\n\r\n2、家里有3岁的宝宝一个，出去就喜欢我抱，我愤怒的问：为什么非要我抱不要爸爸抱？\r\n老公搭腔到：你底盘比较低，她可能有坐跑车的感觉。。。\r\n尼妹，以后他只准座你这越野车！\r\n\r\n\r\n3、和老公闹矛盾，他要喝水我就往水杯里吐了一口口水，他吼道：“你让我还怎么喝呀！ ”\r\n我：快喝吧，正宗太太口服液。\r\n\r\n\r\n4、老婆很肉。今天刚吃完饭，这货就躺下了，我让她别躺了，多长肉啊！......')
# ('二货二起来,笑声响起来', '\r\n\r\n\r\n1、女同事：“你看咱单位，哪有美女啊？”\r\n我：“你照照镜子就知道了。”\r\n女同事：“讨厌。。。”\r\n我：“然后你看谁都是美女了。”\r\n唉！我挨打啦。。。\r\n\r\n\r\n2、下班和实习生一起回家，公交站等车，一乞丐把碗推向实习生乞讨。\r\n这时，实习生不慌不忙的说了句：我不要你的钱，你的钱来的也不容易。\r\n\r\n\r\n3、新交的女友，今天陪她去逛街，路上我不小心摔了一跤，她非但不关心我反而要和我分手，我问她，为什么？\r\n“掉在地上东西我从来不要～”\r\n我-_-\r\n\r\n\r\n4、女友发烧到39.8度，大哭：我要烧成傻子了。......')
# 消费者csv_queue:   44('笑不够的二货男女', '\r\n\r\n\r\n1、晚上约了几个朋友打牌，女友不让去。我也没多说什么，在她脸上轻轻地摸了一下，便走了出去。\r\n直到早上才回到家，不等她开口，我就说：“宝宝，你皮肤弹性也太好了吧！早上摸了一下就被弹出去好远，差点迷路回不来了都。”\r\n\r\n\r\n2、哥们喜欢一女生，终于有一次，他捧着鲜花，当着全班的面向她表白，女生羞羞的问：“你为什么喜欢我？”\r\n哥们说：“虽然你不怎么漂亮，脾气不怎么好，成绩不怎么优秀，在学校也不怎么 起眼，甚至属于中下的一个女生，但我一看到你就有种莫名的感觉，我想这就是。。。”......')
#
# 消费者url_queue:   91
# ('笑说男女,醉人逗语', '\r\n\r\n\r\n1、女生分为两种：一种很粘人，一种未成粘人。\r\n\r\n\r\n2、生病让女生多喝水的男生＝吃饭看电影都说随便的女生。\r\n\r\n\r\n3、谁说带刺的女人都是玫瑰？看脸，不好看的，就是一根狼牙棒而已。\r\n\r\n\r\n4、“天秤男孩求婚最痛苦，因为不知道选哪个膝盖跪地。”\r\n“能选一个女孩出来就不错了。”\r\n\r\n\r\n5、狠心的人三大表现：拿到快递不拆，买了奶茶打包，闹钟响了起床！\r\n\r\n\r\n6、问了很多朋友同一个问题：“当无法两全，你会选择一个你爱的人，还是一个爱你的人？”......')
# ('爆逗,笑的你眼前一黑', '\r\n\r\n\r\n1、“老板，你这个炭怎么不耐烧？”\r\n“因为这是低碳环保产品。”\r\n\r\n\r\n2、营养学家倡导日常生活要素食，还列举了素食的好处：“皮肤白嫩富有弹性，心地善良身材好，最主要的是还可以长生不老。”\r\n有人听了不高兴了，问：“说的这么好，世上有这样的人吗？”\r\n营养学家笑着说：“有啊，唐僧不是吗？”\r\n\r\n\r\n3、昨天去补办身份证，我想换张照片，Pol.ice说了一句话解开了我多年的困惑，他说：“身份证上的照片难看是为了让你好好把它藏起来，不轻易外露，以免丢失，被盗！ ”......')
# ('别笑,他们只是专业路痴很多年', '\r\n\r\n\r\n1、每次朋友问我，你在哪儿？我都说我怎么知道我在哪儿？\r\n\r\n\r\n2、最讨厌别人给我说东南西北，为什么不能说前后左右？\r\n\r\n\r\n3、每次打车，司机师傅问我向哪儿拐，我都好紧张。。。\r\n\r\n\r\n4、大王怕我回不来，不敢叫我去巡山。\r\n\r\n\r\n5、出门遛狗，回家靠狗，人送外号“撒手丢”。\r\n\r\n\r\n6、朋友找我，问我具体位置\r\n“你前面是什么”\r\n“路”\r\n“你后面是什么”\r\n“你旁边是什么”......')
# ('爆笑夫妻之悲催的老公', '\r\n\r\n\r\n1、老婆：“老公，你最喜欢我身体的哪个部位？”\r\n老公想了想，说：“屁股。”\r\n老婆：“讨厌，为什么喜欢那里？”\r\n老公：“嘴会骂我，脸会凶我，手会打我，脚会踢我，只有屁股不会欺负我啊！ ”\r\n老婆：“你信不信，我一屁股坐死你？”\r\n\r\n\r\n2、“哥，你不是去韩国旅游了吗，怎么鼻青脸肿的？”\r\n“因为我没有购物”\r\n“啊！被黑导游打啦？”\r\n“不是，是不老婆打的！ ”\r\n\r\n\r\n3、面对她的无理取闹我有些沉不住气了，无奈地问：“究竟是什么让你如此肆无忌惮？究竟是什么让你产生了我爱你的错觉？”......')
# ('千姿百态的幽默夫妻', '\r\n\r\n\r\n1、有个吃货老婆什么体验，就是你们正在冷战，你嘴巴一动一动的时候，她会萌萌地来一句：你吃的是啥？\r\n\r\n\r\n2、“老公，我今天在商场买衣服花了五六万！ ”\r\n“我的天呐，家里衣柜不够放吧？”\r\n“够，我只买了一件。”\r\n\r\n\r\n3、客厅有点乱，下班回来我满脸无奈地说：“沙发上的衣服不叠，垃圾桶不倒，昨天吃的快餐盒也不收，你眼里咋一点活都没有呢！ ”\r\n老婆：“我眼里都是你，容不下别的。”\r\n我勒个去。。。\r\n\r\n\r\n4、客厅里，媳妇说：你去看看锅里煮的玉米好吗？......')
# 消费者csv_queue:   49
# 消费者url_queue:   91
# ('妙段儿频出的生活吐槽', '\r\n\r\n\r\n1、一首现代诗《头发》\r\n：我的枕头上好多头发，\r\n我的被子上好多头发，\r\n我家地板也都是头发。\r\n唯独我头上没有头发。\r\n\r\n\r\n2、很多人对“车技”的理解就是：能加塞、敢开很快。说白了就是舍得乱踩油门，不怕被撞、拿别人的素质当自己的技术。\r\n\r\n\r\n3、总是碰到很奇妙的事情：一说工资“总体提高”，我一定是拖总体后腿的；一说股市风险“总体可控”，我碰上的一定是套牢的；一说物价“总体平稳”，我要买的一定是不平稳的。。。\r\n\r\n\r\n4、因为没有钱才上班，但为什么我上了班拿了工资还是没有钱，我不明白哪个环节出了问题！难道有中间商赚差价？\r\n\r\n
# 消费者csv_queue:   52
# 消费者url_queue:   90
# 消费者csv_queue:   51
# 消费者url_queue:   90
# 消费者csv_queue:   50
# 消费者url_queue:   90
# 消费者csv_queue:   49
# 消费者url_queue:   90
# 消费者csv_queue:   48
# 消费者url_queue:   90
# 消费者csv_queue:   47
# 消费者url_queue:   90
# 消费者csv_queue:   46
# 消费者url_queue:   90
# 消费者csv_queue:   45
# 消费者url_queue:   90
# 消费者csv_queue:   44
# 消费者url_queue:   90
# 消费者csv_queue:   43
# 消费者url_queue:   90
# 消费者csv_queue:   42
# 消费者url_queue:   90
# 消费者csv_queue:   41
# 消费者url_queue:   90
# ('兔崽子,笑死人你才满意是吧!', '\r\n\r\n\r\n1、爷爷前一阵子把腿摔伤了，出院后，常常在院子里颤颤巍巍的练习走路。\r\n今天，爷爷又在院里练习走路，小明用手机播放起了音乐，给他伴奏。\r\n结果爷爷暴怒：“兔崽子，你放植物大战僵尸的音乐是什么意思？”\r\n\r\n\r\n2、女儿上幼儿园了，回来以后扮演老师给我们上课，自己说着说着，突然捂着裤子说：同学们，老师有尿先去尿尿。\r\n还没走出多远就尿裤子了，我赶紧去给他换，谁知道他竟然说：这位同学回去座好，老师尿裤子了可以自己换。\r\n瞬间我就笑的不行了。。。\r\n\r\n\r\n3、小侄子想玩手机，我逗他：想玩可以，打一巴掌玩10分钟！......')
# ('有趣的一组幽默逗语', '\r\n\r\n\r\n1、只有弱者才会在分手时痛哭流涕求他不要走，我们强者都是跪在地上抱着对方大腿让他寸步难移。\r\n\r\n\r\n2、女孩子找男朋友都要求有上进心。事实上她们遇到有上进心的男人就会要求他们多顾家了。\r\n\r\n\r\n3、男人这一生如果没有娶到最爱的人，就会变得很随意；女人这一生如果没有嫁给最爱的人，就会变得很挑剔。\r\n\r\n\r\n4、问一个很屌丝的问题：如果冰箱一直开着门，可以起到空调一样的效果吗？\r\n\r\n\r\n5、真正爱过的人是不会做朋友的。与其一见肝肠寸断，不如不见烟消云散。\r\n\r\n\r\n6、当你听到：“我们不惜一切代价。。。”时，不要以为你是那个“我们”，可能你只是那个“代价”!\r\n\r\n\r\n7、房地产好比母亲，平时唠唠叨叨，关键时刻一定能换钱，陪在身边不离不弃；......')
# ('尬了半天,不知如何是好', '\r\n\r\n\r\n1、一只老鼠在路边翻着垃圾，我揪起店里正在熟睡的花猫，使劲向老鼠扔去。\r\n猫和老鼠都愣住了，对视了不到一秒，各自扭头就跑。。。\r\n\r\n\r\n2、小时侯有次和哥们一起出去玩，在路上他捡了十块钱，说实话不嫉妒那是假的，于是我让他去小卖部买了些零食花了八块钱，就在我心里有些平衡的时候，结果老板找他四十二。。。\r\n\r\n\r\n3、跟女友求婚：“以前我浑浑噩噩，直到遇到你，我才知道我以后该干什么？”\r\n女友啪地一巴掌：“流氓！ ”\r\n\r\n\r\n4、女同事凑过来说：“昨晚梦到你驾着七彩祥云来看我。”......')
# ('爆糗,都是一脸懵B的样子', '\r\n\r\n\r\n1、小舅子过来跟我借钱买车，我问他借多少？\r\n“车落地多少钱，他说借15万，车落地12万！ ”\r\n“你说反了吧？”\r\n“没有啊！就是借15万，车12万，我得多借3万加油啊！ ”\r\n我。。。\r\n\r\n\r\n2、一个小伙子帮一位老奶奶把行李背到了5楼，正在缓着，老奶奶说：“谢谢你啊，小伙子。你抽不抽烟？”\r\n小伙子：“是的，我抽，谢谢。”\r\n老奶奶：“怪不得呢，年级轻轻上个楼梯还喘气。”\r\n小伙子一脸懵B。。。\r\n\r\n\r\n3、我有一闺蜜喜欢吃酸的东西，一天她去水果店买葡萄吃，老板很热情的招呼道：“我家的葡萄很甜的！随便选！ ”......')
# ('没点儿冷段,热天可怎么过!', '\r\n\r\n\r\n1、日全食：一整天全都在吃东西。\r\n\r\n\r\n2、目击者：能用眼神杀人的人。\r\n\r\n\r\n3、钢筋混凝土：形容一个人土得很倔强！\r\n\r\n\r\n4、秃头和秃顶的区别：秃头是主动秃，秃顶是被动秃。\r\n\r\n\r\n5、宅家的单身狗不一熬夜，好似八旬的老人不起夜，说给谁听谁不信。\r\n\r\n\r\n6、人体的适应性和兼容性是很强的，比如：气体、液体、固体、半液半固体都可以从你的菊花中排出。\r\n\r\n\r\n7、你俩看起来真般配，月老的垃圾分类还做的挺到位。\r\n\r\n\r\n8、小时候总是把不开......')
# 消费者csv_queue:   45
# 消费者url_queue:   90
# ('笑晕你的是父母', '\r\n\r\n\r\n1、儿子问我：粑粑，你说你长得这么丑，麻麻怎么被你搞到手的？\r\n媳妇回答道：当年一个人给了他最大的支持！\r\n儿子：谁呀！\r\n我：你呀！\r\n\r\n\r\n2、吃饭的时候，老妈吃半碗不想吃了，对我爸说：老公，我吃不下了。我爸马上把碗端过来给吃干净了～\r\n我见状也说：爸，我吃不下了。\r\n我爸瞪了我一眼：吃不下你还盛那么多？败家孩子！给我吃干净了，不然以后没你饭吃！\r\n我。。。\r\n\r\n\r\n3、老妈买菜的时候把车停到了路边，结果被巡逻车拍到，理由是“不按规定停车”，罚款200。......')
# ('笑趴你的是熊孩子', '\r\n\r\n\r\n1、儿子上课和同桌打架，双双被罚站。\r\n下课老师问他错了吗，他说知道了。\r\n老师问他错哪儿了？\r\n他说打架不该占用上课时间，应该下课打。。。\r\n于是我就来学校啦！\r\n\r\n\r\n2、平常总是教育儿子不要乱花钱。昨天陪儿子到书店买文具，看到了儿子的学习资料，正想掏钱买，儿子看到了，立马按着我的手说：妈妈，你又乱花钱。。。\r\n\r\n\r\n3、饭桌上，儿子不好好吃饭，在那儿磨磨叽叽，我：趁热，敢快吃，凉了就不好吃了。\r\n儿子来句：热的也不好吃啊！\r\n我。。。\r\n\r\n\r\n4、带孩子坐电梯，电梯人很多，我怕孩子觉得压抑，就把她给抱起来了。......')
# ('领导问我整天发呆,都想点什么?', '\r\n\r\n\r\n公司领导问我：“整天发呆，不知道你都在想些什么！ ”\r\n\r\n\r\n我：我：1.如果我打自己一拳觉得非常痛，我究竟是强壮还是脆弱？\r\n\r\n\r\n2.如果你在看到流星的那一秒立刻许愿，流星可能直到坠落后才听得到你的声音。\r\n\r\n\r\n3.地球那么大，为什么月亮的倒影能够准确地投映在我家院子里的一口井里？\r\n\r\n\r\n4.在闰年生产的保质期一年的牛奶比普通牛奶更能保鲜久一点。\r\n\r\n\r\n5.也许有些人在推荐一本书时，更多的是在推荐读过这本书的自己。\r\n\r\n\r\n6.进大山后的高原反......')
# ('爆囧,个个都是奇葩之星', '\r\n\r\n\r\n1、带小侄子下楼买李子，摊主很热情：随便尝，随便尝。\r\n小侄一听随便尝，顺手抄起一芒果就撕皮。\r\n摊主木着脸称好李子，我过意不去只好又买了几个芒果。\r\n摊主脸这才阴转晴，麻利的称好秤，然后捡了个和侄子尝的大小差不多的芒果放回原处，这才递给我。。。\r\n\r\n\r\n2、公司待遇低，上班时间遛出去开网约车，接的第一单，乘客居然是老板。\r\n我都把车费退给老板了，还是把我开除了。\r\n又应聘了一家公司，新老板把公司前景描绘得一片光明。\r\n为了上班不迟到，我打了辆网约车，没想到遇到老板在兼职。这公司我还能待吗？\r\n\r\n\r\n3、前几年，好朋友开了一个卖馄饨和面条的小店，找了一个女孩当服务员。......')
# ('高冷笑段,适合夏天欣赏', '\r\n\r\n\r\n1、焊工放烟花，有种加班的感觉。\r\n\r\n\r\n2、你们都不知道我们领导每天有多辛苦，骂人都骂出咽炎了。\r\n\r\n\r\n3、“我有一份令人为之惊叹的工作。”\r\n“啥？”\r\n“挖藕。”\r\n\r\n\r\n4、“我以前也不懂事，后来被人打了一顿。”\r\n“就变懂事了？”\r\n“还是不懂事，但不敢嚣张了。”\r\n\r\n\r\n5、朋友见我在喝可乐便说：你怎么喝可乐？杀精的！\r\n我回答：死在里面总比抛尸荒野强。。。\r\n\r\n\r\n6、刚才又接到售楼处打来推销房子的电话，说市中心有个楼盘绿化率55%，要不要考虑下？......')
# ('家里的逗B更爆笑', '\r\n\r\n\r\n1、小时候我妈不让我出去玩，我就藏在门后。如果一会她找不到我真的生气了，我就跳出来说逗你玩的；如果她没什么事我就趁她不注意真的出去玩了。\r\n\r\n\r\n2、每当我们发展点什么兴趣，父母都会说“这玩意能当饭吃？”\r\n而真当我们把吃东西当兴趣时，他们又说：“整天就知道吃。”\r\n\r\n\r\n3、我不能理解有些情侣为什么一吵架就要发朋友圈啊，改签名说单身，我和我父母吵架我也没把状态改成孤儿啊！\r\n\r\n\r\n4、放假了，和娃的战争开始了，时而母慈子孝，连搂带抱！\r\n时而鸡飞狗跳，乌嗷喊叫！......')
# ('搞笑男笑,韵味悠长啊!', '\r\n\r\n\r\n1、猪一样的吃货不可怕，可怕的是猪一样的吃货竟然拥有狗一般的嗅觉！！\r\n\r\n\r\n2、女生的化妆逻辑：不化妆绝不见人，见人才化妆，同事不算人。\r\n\r\n\r\n3、不是吃燕窝的人皮肤好，是吃得起燕窝的人皮肤好。\r\n\r\n\r\n4、丑的人就别轻易跟人家女生表露好感了，会对女生造成负担的。发乎情，止乎礼，让她知道你对她的好感就行了，不用做其他多余的事，这是一个备胎的基本修养。\r\n\r\n\r\n5、其实女孩子很好哄开心的，她全身上下只要有一处亮点，你拎出来夸就行，比如鞋子真好看，项链好精致，眼影很特别等等。。。......')
# 消费者csv_queue:   51('唉,无语了老半天呢!', '\r\n\r\n\r\n1、和闺蜜聊天，我就说为了我的下一代着想，我得找个帅哥结婚。\r\n结果闺蜜说，帅哥为了他的下一代是不会跟你结婚的。\r\n\r\n\r\n2、去食堂打饭，见着一个叫不出名字的菜。手一指：“阿姨，这是什么菜啊？”\r\n隔着透明窗户，那位胖胖的打菜阿姨用穿透玻璃的声音回应道：“腊鸡！你要吗？！ ”\r\n我。。。\r\n\r\n\r\n3、女友不舒服，我陪她去医院，我：“我小时候经常打针，现在一看到穿白衣服的人我就害怕。”\r\n女友：“你的意思是这婚纱照你不打算拍了是吧？”\r\n我。。。\r\n\r\n\r\n4、刚才路过公园，看到两个老爷子在下象棋，于是我就上去凑了个热闹。......')
#
# 消费者url_queue:   90
# ('爆囧,父母和孩子都特无语！', '\r\n\r\n\r\n1、老婆逗儿子说：“我和你爸再给你生个妹妹咋样？”\r\n儿子：“我知道你们这是图省事！ ”\r\n望着我们疑惑的样子，他继续解释道：“不就是等我们长大了直接结婚吗？到时你们就省得再费事给我找老婆了！！ ”\r\n\r\n\r\n2、六岁的小堂弟告诉我，他喜欢上了一个女孩。我问他知道什么叫喜欢吗。\r\n他说：“知道埃本来我不喜欢胖子，但她胖我就很喜欢；我不喜欢别人乱碰我的东西，她乱碰就可以。”\r\n\r\n\r\n3、妈妈：听你同学说，今天你被老师罚站了？\r\n儿子点点头：嗯。\r\n妈妈：为啥？......')
# ('爆囧夫妻,笑到你头大', '\r\n\r\n\r\n1、我和老婆一起在酒店的泳池里游泳，突然泳池里一个五岁小男孩呛了水在挣扎，眼看就要沉下去。\r\n幸亏有我妻子在，小男孩才化险为夷。\r\n——她慌忙从泳池里爬出去通知救生员，于是水位就只到小男孩下巴了。\r\n\r\n\r\n2、“每个人都有自己的幸运色，你的幸运色是什么？”\r\n“红色，每次老婆打我打出血，就不打了。”\r\n“你的幸运色呢？”\r\n“我是黄色，因为老婆打我的时候，一看打出屎来就不打了。”\r\n\r\n\r\n3、去年情人节赶上出差，没时间陪老婆，给老婆发了五百块红包。......')
# ('二货小两口,搞笑小能手', '\r\n\r\n\r\n1、不会再和老婆一起看世界杯了，一晚上解释了不下10次球框旁边站着的那个叫守门员不叫门卫。\r\n\r\n\r\n2、昨晚回家后，老婆像很生气的质问我：“上午手牵手和你一起在水果摊买橘子的那个女孩子是谁？”\r\n我：“老婆，你肯定误会了，我们不是买橘子，是买的橙子。”\r\n\r\n\r\n3、晚上，媳妇又在床上对着一堆钞票磕头作揖：天灵灵、地灵灵，求你下崽行不行？\r\n我拉上窗帘：不炫富会死吗？小心隔窗有眼！我帮你把钱放到保险箱锁上！密码是多少？\r\n媳妇一愣：锤子密码，存钱罐要啥密码？......')
# ('男女搭配,笑果加倍', '\r\n\r\n\r\n1、男友当着家人的面跟我求婚，手捧玫瑰单膝下跪，深情款款的说着甜蜜誓言，要我嫁给他。\r\n正激动又感动的要答应时，发现没有戒指，问他戒指呢？\r\n我哥在旁边说：人家肯吃点亏把你娶了就不错了，还惦记钻戒呢？别做梦了，赶紧醒醒吧。\r\n然后我就睡醒了。。。\r\n\r\n\r\n2、早上吃早点，进来个男的，喊：“服务员，来碗米线，要加大份的！ ”\r\n服务员回到：“不好意思，我们没有大粪做的臊子，你口味可真重。。。”\r\n我对面一大哥噗嗤一声，米线从鼻子里窜出一根。。。\r\n\r\n\r\n3、公司来了几个打暑假工学生。......')
# 消费者csv_queue:   55('幽默的说,活着还是乐观点', '\r\n\r\n\r\n\r\n1、人生还是乐观点，即使身处地狱，也还是能看到魔鬼的身材的。\r\n\r\n\r\n2、道德就是拿火腿肠，喂流浪狗喂到心碎流泪，而完全不用去顾虑猪的感受。\r\n\r\n\r\n3、当你少年时，你的压力，生活的烦恼，没有人理解；当你成人了，你的压力，生活的烦恼，每个人都懂。但没有人在乎。\r\n\r\n\r\n4、抨击社会不公者有三种人：\r\n一是真的很正直有情怀为这个社会变得更好呐喊者；\r\n二是自己不努力却把自己的遭遇归结到社会不公；\r\n最后一种是自己得不到那些不公的机会，一旦有这机会，他比任何人都贪婪不公！\r\n\r\n\r\n5、一个定理：你的专业是A，特长是B，爱好是C。那么你身边必定存在一个人，ABC都比你强。.\r\n\r\n\r\n6、一个人时的孤独，不能算孤独，那只是一个状态;两个人在一起，你感到孤独，那才是真孤独。\r\n\r\n\r\n7、名词解释“决策气球”：有关部门先放出气球，试探一下风向。如果风向没问题，“气球”就变成了真的政策；如果风向不对，“气球”就只是个临时工。......')
#
# 消费者url_queue:   90
# ('笑哭你,气晕你的是熊孩子', '\r\n\r\n\r\n1、在家吃零食看古装剧，看到一个妃子被两个人用被子裹起来，扛着去侍寝。\r\n一旁的小外甥好像要说话，我打住：“不要问，这些事你长大就知道。”\r\n他说：“小姨，如果是你的话，应该要三个人才扛得起来。”\r\n\r\n\r\n2、“老公，你真好，这么多肯德基都给我吃，你也吃点”\r\n“老婆，你吃吧，我不饿”\r\n“老公，谢谢”\r\n“老婆，吃完咱回家吧”\r\n“唉，明年就要读一年级了，不知我们能不能分到同一个班。”\r\n\r\n\r\n3、外甥读幼儿园时，我经常抱着他到处去玩，现在他三年级了不让我抱，我问他为什么？......')
# ('一波家里的搞笑糗事', '\r\n\r\n\r\n1、过节回家，我妈给我买了箱王老吉让我喝。\r\n我说我又不上火，买这干啥？\r\n她说这么大岁数还没对象能不上火吗？我瞅你都上火！\r\n我。。。\r\n\r\n\r\n2、朋友圈把妈妈的微信屏蔽了，晚饭时妈妈问我，你是不是把我微信屏蔽了？\r\n我说：啊，然后就愣住了。\r\n我妈说没关系，反正你们年轻人的圈子我也不懂，我就想问问怎么弄的，我想把你爸给屏蔽了。。\r\n\r\n\r\n3、儿子：爸爸，为什么女的刚结婚叫新娘？\r\n爸爸：这个啊，儿子，你看看爸爸每天都干嘛埃\r\n儿子：你每天给妈妈端茶倒水，洗衣做饭，伺候着妈妈。......')
# 消费者csv_queue:   57
# 消费者url_queue:   89
# 消费者csv_queue:   56
# 消费者url_queue:   89
# 消费者csv_queue:   55
# 消费者url_queue:   89
# 消费者csv_queue:   54
# 消费者url_queue:   89
# 消费者csv_queue:   53
# 消费者url_queue:   89
# 消费者csv_queue:   52
# 消费者url_queue:   89
# 消费者csv_queue:   51
# 消费者url_queue:   89
# ('爆囧,二货让你一脸尬笑', '\r\n\r\n\r\n1、Pol.ice：你知道刚才超速了吗？\r\n我：我老婆快生啦！\r\nPol.ice：但是医院在你开车的反方向。\r\n我：是，我刚才到医院才发现忘记带手机充电器了。\r\n\r\n\r\n2、一次上厕所没带纸，打电话给最好的兄弟江湖救急。\r\n哥们沉默了一下说，你发个定位给我，我来想办法。\r\n半个小时后，厕所外面传来个声音：“请问X先生在哪个蹲位，您的外卖到了加一包餐巾。”\r\n\r\n\r\n3、约女神出去喝酒，经过一翻痛饮，终于，把好灌醉，然后。。。\r\n第二天，女神醒了，一个耳光打了过来，然后抱紧我温柔地说：“亲爱的，是不是很疼？”......')
# ('清凉有笑的幽默小冷段', '\r\n\r\n\r\n1、调查显示：智能手机为公共厕所涂鸦的减少做出了巨大贡献。\r\n\r\n\r\n2、伤不起歌词和西游记是绝配：伤不起真的伤不起～驮着唐三藏跟着三徒弟～良心有木有你的良心狗叼走～一走就是几万里。。。\r\n\r\n\r\n3、大灰狼：小红帽，快开门。\r\n小红帽：你是谁啊？\r\n大灰狼：我是你姥姥。\r\n小红帽：我是你大爷。\r\n\r\n\r\n4、“咱当兵的人，有啥不一样？”\r\n“待遇不一样。”\r\n\r\n\r\n5、一万小时定律：如果你把一万个小时的时间花在同一件事情上，你就会在那件事上成为专家。......')
# ('一波熊孩子,有一个挨揍啦!', '\r\n\r\n\r\n1、晚上，老婆跟儿子说：“我明天要去姥爷家，你去吗？”\r\n儿子听了高兴地说去。\r\n老婆说：“看把你高兴的，你去的目的还不是想让姥爷买糖果给你吃？”\r\n儿子说：“我才不想吃糖果呢。好久没见姥爷了，我只是想看看他个子长高了没有！ ”\r\n\r\n\r\n2、早上吃完早饭发现没带钱 之后让我侄女来赎我。\r\n她拿着10块钱帮我结账后，大喊：走吧！败家玩意儿！\r\n\r\n\r\n3、小时候，我表哥突然鼻青脸肿的来找我：“你以后别老往外跑，你一定要老老实实呆家里好好学习，好不好？！ ”......')
# ('叫人火大的爆笑二货', '\r\n\r\n\r\n1、去参加婚礼，安排座位的是我哥们儿，他说我未婚，要给我安排一桌单身的。\r\n我那个激动啊，心想着指不定还能有个单身女神什么的。。。\r\n后来，把我安排一桌都是小朋友的位置上，还TM让我照顾Ta们都吃好！！！\r\n\r\n\r\n2、和几个朋友喝酒喝多了，走到没有路灯的小路，尿急，就直接开尿了。。。\r\n往左一看，有几个妹子正在走过来，心想，这么黑，她们也看不见。\r\n谁TM会想到，那八个混蛋拿出手机，开着手电筒，帮我照着，说怕我尿到裤子上。。。\r\n\r\n\r\n3、点了个外卖。外卖小哥送来后，我叹息：真羡慕你们这个职业。......')
# 消费者csv_queue:   54('满是套路的二货男女', '\r\n\r\n\r\n1、男：“你能帮我去开会吗？”\r\n女：“什么会？”\r\n男：“我们孩子的家长会。”\r\n\r\n\r\n2、相亲见面之后，女：我不是那种在乎钱，在乎外貌的人。男：现在像你这样的女孩真的少了。你在乎啥？女：我在乎你会啥？男：这个嘛，不是吹的，我啥都会。\r\n女：对不起，我们不合适，我不能和你处对象。\r\n男：为啥？\r\n女：既然你啥都会，你肯定会欺骗我、会背叛我！\xa0\r\n男：尼玛。。。\r\n\r\n\r\n3、终于跟女神表白了，她听后没说什么，而是默默地把我拉到黄河边。。。......')
#
# 消费者url_queue:   89
# ('爆囧,夫妻的笑事儿真是多', '\r\n\r\n\r\n1、今天老婆提出要买一个扫地机器人，被我一顿臭骂！败家玩意，真不知道省钱，还扫地机器人，我不就是？还用买？\r\n\r\n\r\n2、老婆拿着手机，对着手机上的网文说道：“男人偷情的三条标准，我问你答。”\r\n我点头。\r\n老婆问：“第一，最近突然给老婆买玫瑰花”我摇头。\r\n老婆：“第二，突然变得喜欢做菜给老婆吃”我又摇头。\r\n老婆：“第三，突然故意早回家，陪老婆看电视”我又摇头。\r\n老婆又念道：“如果你老公以上三条都没有，恭喜你，你老公肯定不爱你了！ ”\r\n我：“我艹！ ”\r\n\r\n\r\n3、早上出门时，老婆告诉我，晚上做我最喜欢的白菜猪肉馅饺子。......')
# ('生活闲侃,侃的很幽默', '\r\n\r\n\r\n1、一个非常完美、如假包换的增高小技巧：脚底板磨出几公分老茧。\r\n\r\n\r\n2、当代青年四大美德：信息秒回，约见守时，按时还钱，不管闲事。\r\n\r\n\r\n3、我现在严重怀疑一件事，是不是端午节到了，月老拿我的红绳绑粽子了？\r\n\r\n\r\n4、这个勾心斗角的世界啊，还有点儿真情在吗？手机连到电脑上，两者都在询问要不要相信对方。\r\n\r\n\r\n5、我们公司关于台风的通知：明天早上有台风，请各位同事今晚不要回家，以免明天不能来上班。\r\n\r\n\r\n6、现在手上要没个戒指，真的都不好意思捂脸了。\r\n\r\n\r\n7、有些人逢年过节要礼物真的很俗气，不像我只会淡淡问一句：端午都来了，还不发点过节费？\r\n\r\n\r\n8、我国的汽车广告只有两种。......')
# ('爆逗好玩的二货男女', '\r\n\r\n\r\n1、陪女友去公园遛狗，对面有一大胸妹子，我忍不住偷偷瞄了几眼。。。\r\n女友“啪”一声狠狠的拍了一下二哈的脑袋，骂道 ：“你说你贱不贱？顿顿大鱼大肉把你喂的饱饱的，见到一坨屎还是两眼放光！ ”\r\n我。。。\r\n\r\n\r\n2、我常给女友说，遇事儿慌张的时候，喝口水就会镇静下来。\r\n那天，我失足落水，她看见我十分慌张，便喊：“别慌！快喝口水！ ”\r\n\r\n\r\n3、一男一女正准备去一场聚会…\r\n女人：我穿这条裙子显胖吗？\r\n男人：不管我说什么，你都保证不会生气？......')
# ('爆逗爸妈,能把人笑弯了腰', '\r\n\r\n\r\n1、昨晚上梦见我妈给了我一千块钱让买衣服，我很是激动。\r\n接着今早给我妈打电话，我说：“昨晚梦见你了！ ”\r\n我妈问：“梦见啥了？”\r\n我说：“我梦见你给我二千块钱让我随便去买衣服了。”\r\n我妈直接说：“那你梦错了，肯定不是你亲妈！ ”\r\n我。。。\r\n\r\n\r\n2、老妈扔给一张卡：我托人给你介绍了一个对象，在商场见面。\r\n我：干嘛在商场见面啊，给我卡干嘛？\r\n老妈：她喜欢什么，你就直接刷卡。\r\n我：刚见面，干嘛要这样啊？\r\n老妈：这不是为了让她多点时间看商品，少点时间看你的脸吗？......')
# 消费者csv_queue:   62
# 消费者url_queue:   89
# ('Pol.ice打死了一条疯狗', '\r\n\r\n\r\n一个Pol.ice打死了一条疯狗，目击者把这件事告诉了一个喷子。\r\n“Pol.ice打死了。。。”\r\n“谁给他们的权力！？Pol.ice就可以为所欲为吗？就没有一条法律能够监管他们滥用职权吗！？他们造成的悲剧难道还嫌少吗！？”\r\n\r\n\r\n“。。。一条狗。”\r\n“狗怎么了！？难道狗就不是生命吗！？生命有高低贵贱之分吗！？一条鲜活的生命消失了，难道没有人出来为此负责吗！？”\r\n\r\n\r\n“据我所知，那是条疯狗。”\r\n“是不是疯狗由谁来评判！？谁有权力做出这个决定！？你吗！？我吗！？还是别的谁！？有经过鉴定吗！？鉴定程序合法吗！？鉴定人员有利害关系吗！？这里面难道没有任何黑幕吗！？”\r\n\r\n\r\n“当时它正在疯狂地追咬路过的行人。”......')
# ...
# 消费者url_queue:   0
# 消费者csv_queue:   183
# 消费者url_queue:   0
# 消费者csv_queue:   182
# 消费者url_queue:   0
# 消费者csv_queue:   181
# 消费者url_queue:   0
# 消费者csv_queue:   180
# 消费者url_queue:   0
# 消费者csv_queue:   179
# 消费者url_queue:   0
# 消费者csv_queue:   178
# 消费者url_queue:   0
# 消费者csv_queue:   177
# 消费者url_queue:   0
# 消费者csv_queue:   176
# 消费者url_queue:   0
# 消费者csv_queue:   175
# 消费者url_queue:   0
# 消费者csv_queue:   174
# 消费者url_queue:   0
# 消费者csv_queue:   173
# 消费者url_queue:   0
# 消费者csv_queue:   172
# 消费者url_queue:   0
# 消费者csv_queue:   171
# 消费者url_queue:   0
# 消费者csv_queue:   170
# 消费者url_queue:   0
# 消费者csv_queue:   169
# 消费者url_queue:   0
# 消费者csv_queue:   168
# 消费者url_queue:   0
# 消费者csv_queue:   167
# 消费者url_queue:   0
# 消费者csv_queue:   166
# 消费者url_queue:   0
# 消费者csv_queue:   165
# 消费者url_queue:   0
# 消费者csv_queue:   164
# 消费者url_queue:   0
# 消费者csv_queue:   163
# 消费者url_queue:   0
# 消费者csv_queue:   162
# 消费者url_queue:   0
# 消费者csv_queue:   161
# 消费者url_queue:   0
# 消费者csv_queue:   160
# 消费者url_queue:   0
# 消费者csv_queue:   159
# 消费者url_queue:   0
# 消费者csv_queue:   158
# 消费者url_queue:   0
# 消费者csv_queue:   157
# 消费者url_queue:   0
# ('夫妻生活,不幽默日子没法过', '客人走后，妻子向丈夫抱怨道：“你朋友的妻子真没礼貌，我说了不到半个小时的话，她竟然打了30个哈欠。”丈夫：“她不是没礼貌，是想说，插不上嘴。”')
# 消费者csv_queue:   157
# 消费者url_queue:   0
# ('这几对夫妻真好笑', '晚上和老公在床上各玩各的手机。突然老公说：“老子要把微信卸了１我顿时感动泪流，老公终于悔改不在微信上找小mm了。谁知他又说：“摇的全是男的，重新再装一个１')
# 消费者url_queue:   0
#
# ('夫妻间的幽默暗战', '买了瓶美白护肤品，每天起来都细细地擦着。半个月过去了，有天晚上缠住正看新闻的老公：“老公，你看看，我是不是变白了？”老公抬头瞅了我一眼，又扭头看看灯，吐出一句：“咱家的灯咋越来越暗了？”')
# ('夫妻小两口的生活幽默', '这些天里，秋风一刮，老公的脸上就掉皮子。我劝他：“你擦点润肤乳呗，天天掉皮子，不觉得恶心埃”老公：“你懂啥，我这叫帅得掉渣１')
# ('笑翻天的夫妻小两口', '那天下班回家，进门一看，桌子上居然摆了满满一桌子菜，都是我爱吃的。贤妻良母似老婆把我拉到饭桌前坐下，又给我端上一大碗米饭。吃的那个饱啊，吃完后我美美躺在沙发上，老婆却急忙拿出手机，在我面前晃来晃去。突然我打了一个大大的饱嗝。老婆终于得意地大笑起来：“录下来了，录下来了，想弄一个饱嗝做铃音，还真是难啊１。。。')
# ('搞笑的厉害老婆和二货老公', '朋友是个妻管严，那知不知怎么老婆惹了他，他爆怒：“再惹我，形同此纸。”然后把手里的纸撕碎了。老婆二话不说，一巴掌拍到他身上：“我就惹你了，看你怎么着我吧？”说着，双手叉腰，怒目而视。谁知朋友憋了半天，来了句：“你……你这不算惹我。”')
# ('超冷夫妻逗你笑到爆', '一对夫妻吵架，丈夫敢怒不敢言，拿着计算器对着妻子按38，计算器还是会发音的那种。')
# ('生猛爆笑的居家小两口', '老公屁颠屁颠地跟我说，“要不要减肥啊？我玩过胖的，还没玩过瘦的。”我白了他一眼说，“你还没玩过更胖的吧？”老公一脸黑线头……')
# ('夫妻幽默:自恋、逛街和人性化设计', '一对夫妻在看电视剧，古装战争片，妻子看着看着对丈夫嘀咕道：“没想到这古代人也是这么自恋埃”丈夫疑惑的问：“怎么自恋了？”妻：“你看他们举的旗，上面还写了那么大一个‘帅’字。”')
# ('夫妻生活中的乐人爆笑', '“老公，街上要是有人跟我搭讪：美女，我该怎么办？”“那还用问？赶紧把盲人扶过马路。”')
# 消费者csv_queue:   173
# 消费者url_queue:   0
# 消费者csv_queue:   172
# 消费者url_queue:   0
# 消费者csv_queue:   171
# 消费者url_queue:   0
# 消费者csv_queue:   170
# 消费者url_queue:   0
# 消费者csv_queue:   169
# 消费者url_queue:   0
# 消费者csv_queue:   168
# 消费者url_queue:   0
# 消费者csv_queue:   167
# 消费者url_queue:   0
# 消费者csv_queue:   166
# 消费者url_queue:   0
# 消费者csv_queue:   165
# 消费者url_queue:   0
# 消费者csv_queue:   164
# 消费者url_queue:   0
# 消费者csv_queue:   163
# 消费者url_queue:   0
# 消费者csv_queue:   162
# 消费者url_queue:   0
# ('搞笑夫妻斗嘴,看谁被气晕', '早上在厕所拉便便。。喉咙突然很痒，忍不住咳了几声。在客厅的老公关切地问：怎么了噢，是不是噎着了？我。。。')
# ('逗死人的搞笑夫妻', '我说：老婆我们离婚吧，房子存款都给你我净身出户。她把菜刀立案板上说：来吧，先净身，你就可以走了。')
# ('平淡日子里的爆笑夫妻间', '结婚周年纪念日，妻子深情的对丈夫说：“亲爱的，谈谈你这一年来的感受吧。”男人长叹一声，说道：“结婚有风险，办证要谨慎１')消费者csv_queue:   174
#
# 消费者url_queue:   0
# ('超逗的夫妻,笑的乐开花', '老公：“宝贝，我觉得你的人生就像一列火车。”老婆：“为什么呢？”老公：“因为总结起来就是逛——吃——逛——吃——逛吃——逛吃逛吃逛吃……还时不时地555555555……”')
# ('夫妻之间的雷人幽默', '一人得知老婆怀孕，非常高兴。他买来一瓶补胎灵，对老婆说：“你吃后一定有助于胎儿的发育。”他老婆看了半天，把那东西给丢垃圾桶里了，还骂道：“傻货，这是补自行车胎的胶水。”')
# ('经典逗人的幽默夫妻', '几个朋友凑在一起聊天，有人跟一刚结婚的哥们儿开玩笑说：“最近没看见你买酒啊？工资全都交给你老婆了吧１。这时另外一哥们儿苦笑道：“她老婆也就算是一个‘收费站’，我老婆，不只是‘收费站’，还是‘修理厂’呢。天天在家喊着要‘修理我’１')
# ('很会互相挤兑的夫妻', '丈夫和妻子到野外旅游，突然碰到一只老虎，丈夫义无反顾地走上去跟老虎搏斗，最后最终把老虎赶跑。妻子：你真是太勇敢了，那么大的老虎，你居然一点都不怕。丈夫：有什么好怕的！我和你这只母老虎生活在一起这么多年，难道是白混的！妻子：……')
# ('懂幽默的夫妻，生活乐无边', '十一免收高速过路费，我想一家子自己开车出去玩，刚好有朋友也开车去，我问老婆：“我们到底是坐他们的车去还是自己开车去？”老婆白了我一眼，说：“你傻呀，坐他们家的车去，那是他们家省了一千多块钱的过路费，关我们什么事？”')
# 消费者csv_queue:   178
# 消费者url_queue:   0
# 消费者csv_queue:   177
# 消费者url_queue:   0
# 消费者csv_queue:   176
# 消费者url_queue:   0
# 消费者csv_queue:   175
# 消费者url_queue:   0
# 消费者csv_queue:   174
# 消费者url_queue:   0
# 消费者csv_queue:   173
# 消费者url_queue:   0
# 消费者csv_queue:   172
# 消费者url_queue:   0
# 消费者csv_queue:   171
# 消费者url_queue:   0
# 消费者csv_queue:   170
# 消费者url_queue:   0
# 消费者csv_queue:   169
# 消费者url_queue:   0
# ('苦B笑人的夫妻糗事', '老婆要买iphone5。我看了看她大着的肚子说道：“老婆，为了下一代，咱攒点钱，不买iphone5了好吗？”老婆说道：“好吧，那下一代什么时候上市啊？”')
# ('很是幽默的夫妻小两口', '老婆近来要减肥，不仅每天只吃水果、青菜，而且现在连上班都不座公交车了。几天下来，我问她：“减肥效果如何？”老婆：“体重没少，这个月奖金肯定降了不少”不解地问：“为什么？”老婆抓狂道：“因为我步行上班后，天天都迟到。。。”')
# ('夫妻笑话:生孩子、借钱和学开车', '老婆生孩子，老公在产房陪着。孩子生出来，老公兴奋不已，高喊：“老婆，咱生了个儿子１护士在旁边说：“看清楚再说，那是脐带１')
# ('夫妻离婚、怄气、吵嘴等冷幽默', '一对夫妻到律师事务所协议离婚。妻子：“我要求离婚是因为结婚到现在，我讲的话，他从来都不听。”丈夫：“瞎说！这回你要我到律师事务所，我不是来了吗？１')
# ('特别冷人的爆笑夫妻', '那天上网准备买双鞋子。看到一双不错，发了个图片给老公，征求他的意见。几分钟后，老公回复说：“这个女人五官长得还算可以，身材也可以说不错，但是刻意的痕迹太多了……”我大怒：“我让你看的是鞋子１过了几分钟，老公回：“她穿了鞋子我也一样是这样评价啊１')
# ('风趣搞笑的雷人夫妻', '我买了条新连衣裙，穿着一边在屋子里走来走去，一边回头问老公：“这件衣服好看吗？”老公说：“好看，不过你还有一件比这更好看。”我：“哪一件？”老公：“围裙。”')
# ('哈哈,这些过分的丈夫', '一对年轻夫妻结婚才半年，妻子就向法院递交了离婚申请书。法官：“你为什么要离婚？”“因为我丈夫每天都在床上读报。”“这可算不上离婚理由。”“怎么算不上？你要知道，他读的都是征婚广告。”')消费者csv_queue:   185
#
# 消费者url_queue:   0
# ('这些夫妻,冷的没法说', '一中年男在菜市场问卖鱼的：“你这鱼新鲜吗？”鱼贩说：“看这活蹦乱跳的，你说新鲜不新鲜？”该男说：“这可不好说，我老婆也活蹦乱跳的，我就觉得不新鲜。”')
# ('蚯蚓、酒鬼等冷笑话', '\r\n\r\n\r\n1、蚯蚓数年辛劳，终于攒钱开了一家面馆，经营挂面阿方便面阿龙须面阿机切面等等，生意还算红火。\r\n这天，小店又坐得满满当当，可蚯蚓在面板前发愁。别人问：“你咋不给顾客煮面啊？”\r\n蚯蚓哭：“呜呜，他们都要吃手擀面。”\r\n\r\n\r\n2、顾客：“你们端来的是咖啡还是茶水？为什么里面有汽油味？”\xa0\xa0\xa0\xa0\r\n服务员：“有汽油味，就是咖啡，我们这里的茶水带有煤油味。”\r\n\r\n\r\n3、有个酒鬼，后裤袋里插着一瓶威士忌，在街上行走，不巧，他被车撞倒了。他一边起身一边摸摸口袋。他感到有点潮湿。“啊呀！ ”他小声说，“我的上帝啊，但愿是血！ ”\r\n\r\n\r\n4、年过七旬的老爸记忆力逐渐减退。最近，一家医院说要来小区举办“防止老年人记忆力衰退”的又诊活动，老爸说一定要去让医生给看看。昨天，义诊活动开始，老爸欣然前往。......')
# 消费者csv_queue:   186
# 消费者url_queue:   0
# 消费者csv_queue:   185
# 消费者url_queue:   0
# 消费者csv_queue:   184
# 消费者url_queue:   0
# 消费者csv_queue:   183
# 消费者url_queue:   0
# 消费者csv_queue:   182
# 消费者url_queue:   0
# 消费者csv_queue:   181
# 消费者url_queue:   0
# 消费者csv_queue:   180
# 消费者url_queue:   0
# 消费者csv_queue:   179
# 消费者url_queue:   0
# 消费者csv_queue:   178
# 消费者url_queue:   0
# 消费者csv_queue:   177
# 消费者url_queue:   0
# 消费者csv_queue:   176
# 消费者url_queue:   0
# 消费者csv_queue:   175
# 消费者url_queue:   0
# 消费者csv_queue:   174
# 消费者url_queue:   0
# 消费者csv_queue:   173
# 消费者url_queue:   0
# 消费者csv_queue:   172
# 消费者url_queue:   0
# 消费者csv_queue:   171
# 消费者url_queue:   0
# 消费者csv_queue:   170
# 消费者url_queue:   0
# 消费者csv_queue:   169
# 消费者url_queue:   0
# 消费者csv_queue:   168
# 消费者url_queue:   0
# 消费者csv_queue:   167
# 消费者url_queue:   0
# 消费者csv_queue:   166
# 消费者url_queue:   0
# 消费者csv_queue:   165
# 消费者url_queue:   0
# 消费者csv_queue:   164
# 消费者url_queue:   0
# 消费者csv_queue:   163
# 消费者url_queue:   0
# 消费者csv_queue:   162
# 消费者url_queue:   0
# 消费者csv_queue:   161
# 消费者url_queue:   0
# 消费者csv_queue:   160
# 消费者url_queue:   0
# 消费者csv_queue:   159
# 消费者url_queue:   0
# 消费者csv_queue:   158
# 消费者url_queue:   0
# 消费者csv_queue:   157
# 消费者url_queue:   0
# 消费者csv_queue:   156
# 消费者url_queue:   0
# 消费者csv_queue:   155
# 消费者url_queue:   0
# 消费者csv_queue:   154
# 消费者url_queue:   0
# 消费者csv_queue:   153
# 消费者url_queue:   0
# 消费者csv_queue:   152
# 消费者url_queue:   0
# 消费者csv_queue:   151
# 消费者url_queue:   0
# 消费者csv_queue:   150
# 消费者url_queue:   0
# 消费者csv_queue:   149
# 消费者url_queue:   0
# 消费者csv_queue:   148
# 消费者url_queue:   0
# 消费者csv_queue:   147
# 消费者url_queue:   0
# 消费者csv_queue:   146
# 消费者url_queue:   0
# 消费者csv_queue:   145
# 消费者url_queue:   0
# 消费者csv_queue:   144
# 消费者url_queue:   0
# 消费者csv_queue:   143
# 消费者url_queue:   0
# 消费者csv_queue:   142
# 消费者url_queue:   0
# 消费者csv_queue:   141
# 消费者url_queue:   0
# 消费者csv_queue:   140
# 消费者url_queue:   0
# 消费者csv_queue:   139
# 消费者url_queue:   0
# 消费者csv_queue:   138
# 消费者url_queue:   0
# 消费者csv_queue:   137
# 消费者url_queue:   0
# 消费者csv_queue:   136
# 消费者url_queue:   0
# 消费者csv_queue:   135
# 消费者url_queue:   0
# 消费者csv_queue:   134
# 消费者url_queue:   0
# 消费者csv_queue:   133
# 消费者url_queue:   0
# 消费者csv_queue:   132
# 消费者url_queue:   0
# 消费者csv_queue:   131
# 消费者url_queue:   0
# 消费者csv_queue:   130
# 消费者url_queue:   0
# 消费者csv_queue:   129
# 消费者url_queue:   0
# 消费者csv_queue:   128
# 消费者url_queue:   0
# 消费者csv_queue:   127
# 消费者url_queue:   0
# 消费者csv_queue:   126
# 消费者url_queue:   0
# 消费者csv_queue:   125
# 消费者url_queue:   0
# 消费者csv_queue:   124
# 消费者url_queue:   0
# 消费者csv_queue:   123
# 消费者url_queue:   0
# 消费者csv_queue:   122
# 消费者url_queue:   0
# 消费者csv_queue:   121
# 消费者url_queue:   0
# 消费者csv_queue:   120
# 消费者url_queue:   0
# 消费者csv_queue:   119
# 消费者url_queue:   0
# 消费者csv_queue:   118
# 消费者url_queue:   0
# 消费者csv_queue:   117
# 消费者url_queue:   0
# 消费者csv_queue:   116
# 消费者url_queue:   0
# 消费者csv_queue:   115
# 消费者url_queue:   0
# 消费者csv_queue:   114
# 消费者url_queue:   0
# 消费者csv_queue:   113
# 消费者url_queue:   0
# 消费者csv_queue:   112
# 消费者url_queue:   0
# 消费者csv_queue:   111
# 消费者url_queue:   0
# 消费者csv_queue:   110
# 消费者url_queue:   0
# 消费者csv_queue:   109
# 消费者url_queue:   0
# 消费者csv_queue:   108
# 消费者url_queue:   0
# 消费者csv_queue:   107
# 消费者url_queue:   0
# 消费者csv_queue:   106
# 消费者url_queue:   0
# 消费者csv_queue:   105
# 消费者url_queue:   0
# 消费者csv_queue:   104
# 消费者url_queue:   0
# 消费者csv_queue:   103
# 消费者url_queue:   0
# 消费者csv_queue:   102
# 消费者url_queue:   0
# 消费者csv_queue:   101
# 消费者url_queue:   0
# 消费者csv_queue:   100
# 消费者url_queue:   0
# 消费者csv_queue:   99
# 消费者url_queue:   0
# 消费者csv_queue:   98
# 消费者url_queue:   0
# 消费者csv_queue:   97
# 消费者url_queue:   0
# 消费者csv_queue:   96
# 消费者url_queue:   0
# 消费者csv_queue:   95
# 消费者url_queue:   0
# 消费者csv_queue:   94
# 消费者url_queue:   0
# 消费者csv_queue:   93
# 消费者url_queue:   0
# 消费者csv_queue:   92
# 消费者url_queue:   0
# 消费者csv_queue:   91
# 消费者url_queue:   0
# 消费者csv_queue:   90
# 消费者url_queue:   0
# 消费者csv_queue:   89
# 消费者url_queue:   0
# 消费者csv_queue:   88
# 消费者url_queue:   0
# 消费者csv_queue:   87
# 消费者url_queue:   0
# 消费者csv_queue:   86
# 消费者url_queue:   0
# 消费者csv_queue:   85
# 消费者url_queue:   0
# 消费者csv_queue:   84
# 消费者url_queue:   0
# 消费者csv_queue:   83
# 消费者url_queue:   0
# 消费者csv_queue:   82
# 消费者url_queue:   0
# 消费者csv_queue:   81
# 消费者url_queue:   0
# 消费者csv_queue:   80
# 消费者url_queue:   0
# 消费者csv_queue:   79
# 消费者url_queue:   0
# 消费者csv_queue:   78
# 消费者url_queue:   0
# 消费者csv_queue:   77
# 消费者url_queue:   0
# 消费者csv_queue:   76
# 消费者url_queue:   0
# 消费者csv_queue:   75
# 消费者url_queue:   0
# 消费者csv_queue:   74
# 消费者url_queue:   0
# 消费者csv_queue:   73
# 消费者url_queue:   0
# 消费者csv_queue:   72
# 消费者url_queue:   0
# 消费者csv_queue:   71
# 消费者url_queue:   0
# 消费者csv_queue:   70
# 消费者url_queue:   0
# 消费者csv_queue:   69
# 消费者url_queue:   0
# 消费者csv_queue:   68
# 消费者url_queue:   0
# 消费者csv_queue:   67
# 消费者url_queue:   0
# 消费者csv_queue:   66
# 消费者url_queue:   0
# 消费者csv_queue:   65
# 消费者url_queue:   0
# 消费者csv_queue:   64
# 消费者url_queue:   0
# 消费者csv_queue:   63
# 消费者url_queue:   0
# 消费者csv_queue:   62
# 消费者url_queue:   0
# 消费者csv_queue:   61
# 消费者url_queue:   0
# 消费者csv_queue:   60
# 消费者url_queue:   0
# 消费者csv_queue:   59
# 消费者url_queue:   0
# 消费者csv_queue:   58
# 消费者url_queue:   0
# 消费者csv_queue:   57
# 消费者url_queue:   0
# 消费者csv_queue:   56
# 消费者url_queue:   0
# 消费者csv_queue:   55
# 消费者url_queue:   0
# 消费者csv_queue:   54
# 消费者url_queue:   0
# 消费者csv_queue:   53
# 消费者url_queue:   0
# 消费者csv_queue:   52
# 消费者url_queue:   0
# 消费者csv_queue:   51
# 消费者url_queue:   0
# 消费者csv_queue:   50
# 消费者url_queue:   0
# 消费者csv_queue:   49
# 消费者url_queue:   0
# 消费者csv_queue:   48
# 消费者url_queue:   0
# 消费者csv_queue:   47
# 消费者url_queue:   0
# 消费者csv_queue:   46
# 消费者url_queue:   0
# 消费者csv_queue:   45
# 消费者url_queue:   0
# 消费者csv_queue:   44
# 消费者url_queue:   0
# 消费者csv_queue:   43
# 消费者url_queue:   0
# 消费者csv_queue:   42
# 消费者url_queue:   0
# 消费者csv_queue:   41
# 消费者url_queue:   0
# 消费者csv_queue:   40
# 消费者url_queue:   0
# 消费者csv_queue:   39
# 消费者url_queue:   0
# 消费者csv_queue:   38
# 消费者url_queue:   0
# 消费者csv_queue:   37
# 消费者url_queue:   0
# 消费者csv_queue:   36
# 消费者url_queue:   0
# 消费者csv_queue:   35
# 消费者url_queue:   0
# 消费者csv_queue:   34
# 消费者url_queue:   0
# 消费者csv_queue:   33
# 消费者url_queue:   0
# 消费者csv_queue:   32
# 消费者url_queue:   0
# 消费者csv_queue:   31
# 消费者url_queue:   0
# 消费者csv_queue:   30
# 消费者url_queue:   0
# 消费者csv_queue:   29
# 消费者url_queue:   0
# 消费者csv_queue:   28
# 消费者url_queue:   0
# 消费者csv_queue:   27
# 消费者url_queue:   0
# 消费者csv_queue:   26
# 消费者url_queue:   0
# 消费者csv_queue:   25
# 消费者url_queue:   0
# 消费者csv_queue:   24
# 消费者url_queue:   0
# 消费者csv_queue:   23
# 消费者url_queue:   0
# 消费者csv_queue:   22
# 消费者url_queue:   0
# 消费者csv_queue:   21
# 消费者url_queue:   0
# 消费者csv_queue:   20
# 消费者url_queue:   0
# 消费者csv_queue:   19
# 消费者url_queue:   0
# 消费者csv_queue:   18
# 消费者url_queue:   0
# 消费者csv_queue:   17
# 消费者url_queue:   0
# 消费者csv_queue:   16
# 消费者url_queue:   0
# 消费者csv_queue:   15
# 消费者url_queue:   0
# 消费者csv_queue:   14
# 消费者url_queue:   0
# 消费者csv_queue:   13
# 消费者url_queue:   0
# 消费者csv_queue:   12
# 消费者url_queue:   0
# 消费者csv_queue:   11
# 消费者url_queue:   0
# 消费者csv_queue:   10
# 消费者url_queue:   0
# 消费者csv_queue:   9
# 消费者url_queue:   0
# 消费者csv_queue:   8
# 消费者url_queue:   0
# 消费者csv_queue:   7
# 消费者url_queue:   0
# 消费者csv_queue:   6
# 消费者url_queue:   0
# 消费者csv_queue:   5
# 消费者url_queue:   0
# 消费者csv_queue:   4
# 消费者url_queue:   0
# 消费者csv_queue:   3
# 消费者url_queue:   0
# 消费者csv_queue:   2
# 消费者url_queue:   0
# 消费者csv_queue:   1
# 消费者url_queue:   0
# 消费者csv_queue:   0
# 消费者url_queue:   0
